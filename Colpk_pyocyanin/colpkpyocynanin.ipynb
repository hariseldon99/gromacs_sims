# %% [markdown]
# Colicin PK protein and Pyocynain Complex
# ======================

# %% [markdown]
# ## ``Gromacs_py`` simulation
#
# Here is an example of a short simulation of the Colicin PK (`colpk`) protein in complex with pyocyanin (`py`) ligand using AMBER force-field model.
#
# Need to do this to properly docked system. The PDB file of ligand must be generated from the canonical SMILES by rdkit. This can be done locally using:
#
# Finally, nine successive steps are used:
#
# 1. Load the protein in its best -docked state.
#
# 2. In-complex creation of Protein Topology using ``GmxSys.add_top()``, followed by boxing and solvation/neutralization.
#
# 3. Boxing of complex.
#
# 4. Ideally, Ligand topology creation using `prepare_top()` which uses `acpype` to build ligand topology. This did not work, so must do this manually using `acpype` externally
#
# 5. Solvate complex and add ions.
#
# 6. Minimisation of the structure using ``GmxSys.em_2_steps()``.
#
# 7. Equilibration of the system using ``GmxSys.em_equi_three_step_iter_error()``.
#
# 8. Production run using ``GmxSys.production()``.
#
# 9.  Post-processing using `GmxSys.convert_trj().`
#
# ### Import

# %%
import sys
import os
import shutil

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## To use `gromacs_py` in a project

# %%
from gromacs_py import gmx

# %% [markdown]
# ## Simulation setup
#
# - Define a few variables for you simulation, like:
#
#     1. simulation output folders
#     2. ionic concentration
#     3. number of minimisation steps
#     4. equilibration and production time
#
# ### Regarding equilibriation time:
# The following variables define the sim times (relative units) for each stage of the three-stage equilibriation process. Check notes below for details:
#
# 1. `HA_time`
# 2. `CA_time`
# 3. `CA_LOW_time`

# %%
DATA_OUT = 'colpk_pyc_complex'

# System Setup
vsite='none'
sys_top_folder = os.path.join(DATA_OUT, 'sys_top')
#ignore_hydrogen = {'ignh': None}

# Energy Minimisation
em_folder = os.path.join(DATA_OUT, 'em')
em_sys_folder = os.path.join(DATA_OUT, 'sys_em')
em_step_number = 10000
emtol = 10.0  	# Stop minimization when the maximum force < 10 J/mol
emstep  = 0.01      # Energy step size


# Equillibration
equi_folder = os.path.join(DATA_OUT, 'sys_equi')
HA_time = 0.5
CA_time = 1.0
CA_LOW_time = 4.0

dt_HA = 0.001
dt = 0.002

HA_step = 1000 * HA_time / dt_HA
CA_step = 1000 * CA_time / dt
CA_LOW_step = 1000 * CA_LOW_time / dt

# Production
os.makedirs(DATA_OUT, exist_ok = True)
prod_folder = os.path.join(DATA_OUT, 'sys_prod')
prod_time = 50.0

prod_step = 1000 * prod_time / dt

# %% [markdown]
# ## Create the `GmxSys` object
#
# Load protein information only from docked PDB file on disk

# %%
# %%script true
#
# pdb_file = "pdbs/colpk_pyc.pdb"
# sys_name = "colpk_pyc_complex"
# complex_sys = gmx.GmxSys(name=sys_name, coor_file=pdb_file)

# %% [markdown]
# ## Create topology and stuff
#
# 1. Topology creation involves using `pdb2gmx` via the `prepare_top()` function.
# 2. Create box

# %%
# %%script true
# complex_sys.prepare_top(out_folder=DATA_OUT, ff='amber99sb-ildn')
# Out:
# pdb2pqr30 --ff AMBER --ffout AMBER --keep-chain --titration-state-method=propka --with-ph=7.00 tmp_pdb2pqr.pdb 00_colpk_pyc_complex.pqr
# gmx pdb2gmx -f 01_colpk_pyc_complex_good_his.pdb -o colpk_pyc_complex_pdb2gmx.pdb -p colpk_pyc_complex_pdb2gmx.top -i colpk_pyc_complex_posre.itp -water tip3p -ff amber99sb-ildn -ignh -vsite none

# %% [markdown]
# ## Create Ligand topology and transclude manually to complex topology
#
# Doing this automatically in `gromacs_py` is buggy and doesn't work, necessitating manual overrides.
#
# 1. First, you need to add ALL hydrogen atoms into the PDB file of the best-docked ligand pose using pymol gui:
#     Load the ligand pdb into pymol, then click `builder -> add H` from the top right buttons. Save to new file
# 2. Then run `acpype -i` on the resultant PDB from shell. These yield full ligand topology for multiple force fields. We're using the default AMBER force field here.
#
# **Note:** `acpype` crashed because the openbabel-protonated molecule was not electrically neutral, so I reran with ` acpype -i pyc_h.pdb -n 1`. Now the protonated molecule is charged.**However**, this caused the ligand to get repelled by the protein in the dynamics, so I'm re-running after protonating it in `PyMol` instead of openbabel.
#
# 3. Next, copy-paste the contents of the ligand's amber force field topology file transclusions to the top of the complex topology file, AND the molecules section of the ligand's topology file to the molecules section of the complex topology file.
#
# **Note:** The ligand information MUST come FIRST in the complex topology, as there are new atomtypes in there and those must be defined first before any `moleculetype`. [See this](https://gromacs.bioexcel.eu/t/invalid-order-for-directive-atomtypes-error/3859)
#
# 4. Make sure to adjust the paths of all transcluded files.
#
# 5. Finally, update the complex PDB file with ligand co-ordinates from the best-docked pose using `pymol`.

# %%
# %%script true
# complex_sys.display()
# Out:
# name         : colpk_pyc_complex
# coor_file    : colpk_pyc_complex/colpk_pyc_complex_pdb2gmx.pdb
# top_file     : colpk_pyc_complex/colpk_pyc_complex_pdb2gmx.top
# nt           : 0
# ntmpi        : 0
# sys_history  : 0

# %%
# %%script true
# complex_sys.create_box(dist=1.5, box_type="dodecahedron", check_file_out=True)
# complex_sys.solvate_add_ions(out_folder=DATA_OUT, name=sys_name,create_box_flag=False, maxwarn=4)
# complex_sys.display()
# Out:
# gmx editconf -f colpk_pyc_complex/colpk_pyc_complex_pdb2gmx.pdb -o colpk_pyc_complex/colpk_pyc_complex_pdb2gmx_box.pdb -bt dodecahedron -d 1.5
# gmx grompp -f ../../usr/local/lib/python3.12/site-packages/gromacs_py/gmx/template/mini.mdp -c colpk_pyc_complex_water.pdb -r colpk_pyc_complex_water.pdb -p colpk_pyc_complex_water_ion.top -po out_mini.mdp -o genion_colpk_pyc_complex_water_ion.tpr -maxwarn 4
# gmx genion -s genion_colpk_pyc_complex_water_ion.tpr -p colpk_pyc_complex_water_ion.top -o colpk_pyc_complex_water_ion.gro -np 260 -pname NA -nn 259 -nname CL
# name         : colpk_pyc_complex
# sim_name     : genion_colpk_pyc_complex_water_ion
# coor_file    : colpk_pyc_complex/colpk_pyc_complex_water_ion.gro
# top_file     : colpk_pyc_complex/colpk_pyc_complex_water_ion.top
# tpr          : colpk_pyc_complex/genion_colpk_pyc_complex_water_ion.tpr
# mdp          : ../usr/local/lib/python3.12/site-packages/gromacs_py/gmx/template/mini.mdp
# nt           : 0
# ntmpi        : 0
# sys_history  : 0

# %% [markdown]
# ## Add index groups
#
# Now, we have to add the following index groups: Merge the Protein with the ligand (PYC) with the shell command
#
# ```bash
# gmx make_ndx -f colpk_pyc_complex_water_ion.gro -o colpk_pyc_complex_water_ion.ndx
# ```
# Merge group 1 with group 13 to form `Protein_PYC` group. We can now set temperature control groups to = `Protein_PYC` and `Water_and_ions` later.
#
# Finally, add the index file to the `complex_sys` object.

# %%
# %%script true
# complex_sys.add_ndx("",ndx_name="colpk_pyc_complex_water_ion", folder_out=DATA_OUT)

# %% [markdown]
# ## Energy minimisation
#
# Set parallelization and GPU options here. Change them later, if needed.

# %%
# %%script true
# #Parallelization
# nthreads = int(os.environ.get('PBS_NCPUS', '12'))
#
# #Set Parallelization
# complex_sys.nt = nthreads
# #complex_sys.ntmpi = 1
# complex_sys.gpu_id = '0'
#
# complex_sys.em_2_steps(out_folder=em_folder,
#         no_constr_nsteps=em_step_number,
#         constr_nsteps=em_step_number,
#         posres="",
#         create_box_flag=False, emtol=emtol, emstep=emstep)
# Out:
# WARNING !!! ADDING unusual parameter : "emtol"in the mdp file Init_em_colpk_pyc_complex.mdp
# WARNING !!! ADDING unusual parameter : "emstep"in the mdp file Init_em_colpk_pyc_complex.mdp
# gmx grompp -f Init_em_colpk_pyc_complex.mdp -c ../colpk_pyc_complex_water_ion.gro -r ../colpk_pyc_complex_water_ion.gro -p ../colpk_pyc_complex_water_ion.top -po out_Init_em_colpk_pyc_complex.mdp -o Init_em_colpk_pyc_complex.tpr -maxwarn 1 -n ../colpk_pyc_complex_water_ion.ndx
# gmx mdrun -s Init_em_colpk_pyc_complex.tpr -deffnm Init_em_colpk_pyc_complex -nt 12 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/10000 [00:00<?, ?it/s]
# WARNING !!! ADDING unusual parameter : "emtol"in the mdp file colpk_pyc_complex.mdp
# WARNING !!! ADDING unusual parameter : "emstep"in the mdp file colpk_pyc_complex.mdp
# gmx grompp -f colpk_pyc_complex.mdp -c Init_em_colpk_pyc_complex.gro -r Init_em_colpk_pyc_complex.gro -p ../colpk_pyc_complex_water_ion.top -po out_colpk_pyc_complex.mdp -o colpk_pyc_complex.tpr -maxwarn 1 -n ../colpk_pyc_complex_water_ion.ndx
# gmx mdrun -s colpk_pyc_complex.tpr -deffnm colpk_pyc_complex -nt 12 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# ## Plot energy:

# %%
# %%script true
# ener_pd_1 = complex_sys.sys_history[-1].get_ener(selection_list=['Potential'])
# ener_pd_2 = complex_sys.get_ener(selection_list=['Potential'])
#
# ener_pd_1['label'] = 'no bond constr'
# ener_pd_2['label'] = 'bond constr'
#
# ener_pd = pd.concat([ener_pd_1, ener_pd_2])
#
# ener_pd['Time (ps)'] = np.arange(len(ener_pd))
# Out:
# gmx energy -f colpk_pyc_complex/em/Init_em_colpk_pyc_complex.edr -o tmp_edr.xvg
# gmx energy -f colpk_pyc_complex/em/colpk_pyc_complex.edr -o tmp_edr.xvg

# %%
# %%script true
# ax = sns.lineplot(x="Time (ps)", y="Potential",
#         hue="label",
#         data=ener_pd)
# ax.set_xlabel('step')
# ax.set_ylabel('energy (KJ/mol)')
# plt.grid()

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.em_' + datetime.date.today().strftime("%Y%m%d") + ".pycpt"
# with open(chkpt_fname, 'wb') as py_cpt:
#     pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ## From here, run in cluster
# ### System minimisation and equilibration
#
# Based on `gromacs_py` docs, this is a 3-stage equilibriation process.
#
# All three steps seem to be NPT with berendsen coupling and v-rescale for temp coupling. Each step just has different restraints. This does not seem so bad: closer to lab conditions.
#
# Since the statistical ensemble is pretty much always NPT, this is different from the Lemkul-lysozyme tutorial at [MDTutorials](http://www.mdtutorials.com/gmx/lysozyme/).
#
# **Note:**
# 1. Had to run this on cluster at least. Too slow even in ofc workstn.
# 2. Temperature coupling groups have to be set properly. See [mdtutorials](http://www.mdtutorials.com/gmx/complex/06_equil.html) and [gromacs-py manual](https://gromacs-py.readthedocs.io/en/latest/notebook/01_dna_ligand_ambertools.html#System-equilibration)
# 3. Ligand name is `PYC` as seen in the index file by visual inspection.

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.em_20250116.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %%
# %%script true
# #Parallelization
# nthreads = int(os.environ.get('PBS_NCPUS', '12'))
#
# #Set Parallelization
# complex_sys.nt = nthreads
# #complex_sys.ntmpi = 1
# complex_sys.gpu_id = '0'
#
# complex_sys.em_equi_three_step_iter_error(out_folder=equi_folder,
#         no_constr_nsteps=em_step_number,
#         constr_nsteps=em_step_number,
#         nsteps_HA=HA_step,
#         nsteps_CA=CA_step,
#         nsteps_CA_LOW=CA_LOW_step,
#         dt=dt, dt_HA=dt_HA,
#         tc_grps='Protein_PYC Water_and_ions',
#         tau_t= '0.1 0.1',
#         ref_t= '310 310',
#         vsite=vsite, maxwarn=10, iter_num=1)

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.equi_' + datetime.date.today().strftime("%Y%m%d") + ".pycpt"
# with open(chkpt_fname, 'wb') as py_cpt:
#     pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ### Plot Equilibriation
#
# Since the statistical ensemble is pretty much always NPT, this is different from the Lemkul-lysozyme tutorial at [MDTutorials](http://www.mdtutorials.com/gmx/lysozyme/). So we need to see Volume as well as Pressure, temperature, and density.

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.equi_20250117.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %%
# %%script true
# quantities = ["Temperature", "Pressure", "Volume", "Density"]
# units = ["$K$", "$bar$", "$A^3$", "$kg/m^3$"]
#
# pd_1 = complex_sys.sys_history[-2].get_ener(selection_list=quantities)
# pd_2 = complex_sys.sys_history[-1].get_ener(selection_list=quantities)
# pd_3 = complex_sys.get_ener(selection_list=quantities)
#
# pd_1['label'] = 'HA_constr'
# pd_2['label'] = 'CA_constr'
# pd_2['Time (ps)'] = pd_2['Time (ps)'] + pd_1['Time (ps)'].max()
# pd_3['label'] = 'CA_LOW_constr'
# pd_3['Time (ps)'] = pd_3['Time (ps)'] + pd_2['Time (ps)'].max()
#
# display(pd.concat([pd_1, pd_2, pd_3]))
# Out:
# gmx energy -f colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.edr -o tmp_edr.xvg
# gmx energy -f colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.edr -o tmp_edr.xvg
# gmx energy -f colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.edr -o tmp_edr.xvg
#      Time (ps)  Temperature     Pressure       Volume     Density  \
# 0          0.0     0.009970 -4828.049316  3006.061523  983.551941
# 1          5.0   309.290314    26.690306  2985.448242  990.342957
# 2         10.0   310.170441   -18.579214  2990.293945  988.738098
# 3         15.0   310.457397    47.871204  2992.520508  988.002441
# 4         20.0   310.467133    31.316626  2993.116699  987.805664
# ..         ...          ...          ...          ...         ...
# 396     5460.0   309.484009   -78.096786  3004.098877  984.194519
# 397     5470.0   310.116913   -56.089092  2996.120361  986.815369
# 398     5480.0   309.522949   113.479462  2986.278076  990.067749
# 399     5490.0   310.327698    66.533546  2988.656494  989.279846
# 400     5500.0   309.980042    41.710705  2995.232422  987.107910
#
#              label
# 0        HA_constr
# 1        HA_constr
# 2        HA_constr
# 3        HA_constr
# 4        HA_constr
# ..             ...
# 396  CA_LOW_constr
# 397  CA_LOW_constr
# 398  CA_LOW_constr
# 399  CA_LOW_constr
# 400  CA_LOW_constr
#
# [603 rows x 6 columns]

# %%
# %%script true
# plt.rcParams.update({'font.size': 22})
#
# fig, axs = plt.subplots(4, 1, figsize=(24,13.5), sharex=True, tight_layout=True)
#
# for ax, quantity, unit in zip(axs, quantities, units):
#     for df in (pd_1, pd_2, pd_3):
#         ax.plot(df["Time (ps)"], df[quantity], label=str(df['label'][0]))
#         ax.set_ylabel(quantity + "(" + unit + ")")
#         ax.grid()
#
# axs[0].legend()
# axs[-1].set_xlabel("Time (ps)");

# %% [markdown]
# Looks okay to me. Fluctuations are high at the end because CA constraints are low, but there is a well-defined average.

# %% [markdown]
# ### Plot RMSD
#
# There is a corrupted frame in the `xtc` (probably took place during checkpoint restore) due to which this doesn't work. Nonetheless, the `gro` file of the final state looks good, so will proceed to production MD.

# %%
# %%script true
# # Define reference structure for RMSD calculation
# ref_sys =  complex_sys.sys_history[1]
# struct="Protein"
#
# rmsd_pd_1 = complex_sys.sys_history[-2].get_rmsd([struct, struct], ref_sys=ref_sys)
# rmsd_pd_2 = complex_sys.sys_history[-1].get_rmsd([struct, struct], ref_sys=ref_sys)
# rmsd_pd_3 = complex_sys.get_rmsd([struct, struct], ref_sys=ref_sys)
#
#
# rmsd_pd_1['label'] = 'HA_constr'
# rmsd_pd_2['label'] = 'CA_constr'
# rmsd_pd_2['time'] = rmsd_pd_2['time'] + rmsd_pd_1['time'].max()
# rmsd_pd_3['label'] = 'CA_LOW_constr'
# rmsd_pd_3['time'] = rmsd_pd_3['time'] + rmsd_pd_2['time'].max()
#
# display(pd.concat([rmsd_pd_1, rmsd_pd_2, rmsd_pd_3]))
# Out:
# gmx rms -s colpk_pyc_complex/em/Init_em_colpk_pyc_complex.tpr -f colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.xtc -n colpk_pyc_complex/colpk_pyc_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
# gmx rms -s colpk_pyc_complex/em/Init_em_colpk_pyc_complex.tpr -f colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.xtc -n colpk_pyc_complex/colpk_pyc_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
# gmx rms -s colpk_pyc_complex/em/Init_em_colpk_pyc_complex.tpr -f colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.xtc -n colpk_pyc_complex/colpk_pyc_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
#        time   Protein          label
# 0       0.0  2.090764      HA_constr
# 1       5.0  2.086084      HA_constr
# 2      10.0  2.087462      HA_constr
# 3      15.0  2.088505      HA_constr
# 4      20.0  2.086428      HA_constr
# ..      ...       ...            ...
# 396  5460.0  2.048875  CA_LOW_constr
# 397  5470.0  2.080521  CA_LOW_constr
# 398  5480.0  2.060852  CA_LOW_constr
# 399  5490.0  2.045402  CA_LOW_constr
# 400  5500.0  2.126582  CA_LOW_constr
#
# [603 rows x 3 columns]

# %%
# %%script true
# fig, ax = plt.subplots(1, 1, figsize=(24,13.5))
#
# for df in (rmsd_pd_1, rmsd_pd_2, rmsd_pd_3):
#         ax.plot(df["time"], df["Protein"], label=str(df['label'][0]))
#
# ax.set_title(struct)
# ax.set_ylabel('RMSD (nm)')
# ax.set_xlabel('Time (ps)')
# plt.grid()

# %% [markdown]
# ## Production MD
#
# tc-coupling groups are required here as well. See [gromacs-py manual](https://gromacs-py.readthedocs.io/en/latest/notebook/01_dna_ligand_ambertools.html#Production)

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.equi_20250117.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %%
# %%script true
# #Parallelization
# nthreads = int(os.environ.get('PBS_NCPUS', '16'))
#
# #Set Parallelization
# complex_sys.nt = nthreads
# #complex_sys.ntmpi = 1
# complex_sys.gpu_id = '0'
#
# complex_sys.production(out_folder=prod_folder,
#         nsteps=prod_step,
#         tc_grps='Protein_PYC Water_and_ions',
#         tau_t= '0.1 0.1',
#         ref_t= '310 310',
#         dt=dt, vsite=vsite, maxwarn=1, nstlist=200)

# %% [markdown]
# ## Checkpointing for extending

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.prod_' + datetime.date.today().strftime("%Y%m%d") + '.pycpt'
# with open(chkpt_fname, 'wb') as py_cpt:
#     pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ## Post-Production

# %%
#%%script true
import pickle, datetime
chkpt_fname='checkpoint.prod_20250118.pycpt'

with open(chkpt_fname, 'rb') as py_cpt:
    complex_sys = pickle.load(py_cpt)

# %% [markdown]
# ### Prepare Production Trajectory for Viewing
#
# #### Center Trajectory

# %%
#%%script true
# Center trajectory
complex_sys.center_mol_box(traj=True)
# Out:
# gmx make_ndx -f colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.gro -o colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.xtc -o colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex_compact.xtc -s colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.tpr -ur tric -pbc mol -center yes -n colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.ndx

# %% [markdown]
# ## Final Steps
# As in any simulation conducted with periodic boundary conditions, molecules may appear "broken" or may "jump" back and forth across the box. To recenter the protein and rewrap the molecules within the unit cell to recover the desired box shape, invoke trjconv.
#
# Choose "Protein" for centering and "System" for output.

# %%
#%%script true
complex_sys.convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none')
# Out:
# gmx trjconv -f colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex_compact.xtc -o colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex_compact_compact.xtc -s colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.tpr -ur compact -pbc none -fit rot+trans -n colpk_pyc_complex/sys_prod/prod_colpk_pyc_complex.ndx

# %% [markdown]
# #### Extract production initial condition
# Optionally, extract the first frame of the final prod traj (latest from history, as the running one got updated) into a `pdb` for loading into post processing.

# %%
#%%script true
complex_sys.sys_history[-1].convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none', specific_coor_out=prod_folder+"/start.pdb", dump="0")
# Out:
# gmx trjconv -f colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.xtc -o colpk_pyc_complex/sys_prod/start.pdb -s colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.tpr -ur compact -pbc none -dump 0 -fit rot+trans -n colpk_pyc_complex/colpk_pyc_complex_water_ion.ndx

# %% [markdown]
# ### Cleanup older trajectories the same way

# %%
#%%script true
complex_sys.sys_history[5].display()
# Out:
# name         : colpk_pyc_complex
# sim_name     : equi_HA_colpk_pyc_complex
# coor_file    : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.gro
# top_file     : colpk_pyc_complex/colpk_pyc_complex_water_ion.top
# tpr          : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.tpr
# ndx          : colpk_pyc_complex/colpk_pyc_complex_water_ion.ndx
# mdp          : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.mdp
# xtc          : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.xtc
# edr          : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.edr
# log          : colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.log
# nt           : 32
# ntmpi        : 0
# gpu_id       : 0
# sys_history  : 0

# %% [markdown]
# Visual inspection of sys_history shows that elements 5,6,7 contain the equilibration history.

# %%
#%%script true
idx = [5,6,7]

for i in idx:
    try:
        complex_sys.sys_history[i].center_mol_box(traj=True)
        complex_sys.sys_history[i].convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none')
    except:
        pass
# Out:
# gmx make_ndx -f colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.gro -o colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.xtc -o colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.tpr -ur tric -pbc mol -center yes -n colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex_compact.xtc -o colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex_compact_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.tpr -ur compact -pbc none -fit rot+trans -n colpk_pyc_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_colpk_pyc_complex.ndx
# gmx make_ndx -f colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.gro -o colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.xtc -o colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.tpr -ur tric -pbc mol -center yes -n colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex_compact.xtc -o colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex_compact_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.tpr -ur compact -pbc none -fit rot+trans -n colpk_pyc_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_colpk_pyc_complex.ndx
# gmx make_ndx -f colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.gro -o colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_prod/start.pdb -o colpk_pyc_complex/sys_prod/start_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.tpr -ur tric -pbc mol -center yes -n colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.ndx
# gmx trjconv -f colpk_pyc_complex/sys_prod/start_compact.xtc -o colpk_pyc_complex/sys_prod/start_compact_compact.xtc -s colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.tpr -ur compact -pbc none -fit rot+trans -n colpk_pyc_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_colpk_pyc_complex.ndx
