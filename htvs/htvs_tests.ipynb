# %% [markdown]
# # Programmatic implementation of AMDock pipeline
#
# Testing the programmatic htvs via the `AMDock` workflow. `AMDock` is a nive GUI for autodock that works very well. Below is a test run of my `htvs_amdock` module that tries to programmatically replicate the same workflow as `AMDock`.
#
# ## Preparation
#
# 1. Download the test complex [1HSG protein with mk1 ligand](https://www.rcsb.org/structure/1HSG). Separate the protein and ligand pdb data in `pymol`.
# 2. Do not download the ligand structure from any other source. Use the one in the complex, as it is experimentally verified.
# 3. To reduce the possibility of false positives, the ligand PDB, once extracted from the experimentally verified crystal pose, was manually moved/rotated about in pymol by a random distance and angle.

# %%
import importmonkey
import os

# set OMP_NUM_THREADS to number of available CPUs. Best for docking a single complex quickly
cpus = os.cpu_count() or 1
os.environ["OMP_NUM_THREADS"] = str(cpus)
home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hsg_mk1/experiment/1hsg_protein.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hsg_mk1/experiment/mk1.pdb")

testjob = [{
            "protein_name": "1hsg_protein",
            "ligand_name": "mk1",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1hsg_mk1/job_1hsg_mk1_script_20251206"),
        }]

# Uncomment this to rerun the docking
#run_htvs(testjob)

# %% [markdown]
# ## AutoLigand error (resolved)
#
# ======== AutoLigand Site Search (Automatic) FAILED STDOUT ========
#
# ======== AutoLigand Site Search (Automatic) FAILED STDERR ========
# ```python
# Traceback (most recent call last):
#   File "/usr/local/miniforge3/envs/htvs/bin/AutoLigand", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/miniforge3/envs/htvs/lib/python3.12/site-packages/AutoDockTools/AutoLigand.py", line 198, in main
#     word = string.split(linee)
#            ^^^^^^^^^^^^
# AttributeError: module 'string' has no attribute 'split'
# ```
#
# The `split()` function was deprecated and the functionality moved to a `xxx.split()` method during upgrade from python 2 to python 3. The `AutoLigand` script taken from [AutoDockTools_py3](https://github.com/Valdes-Tresanco-MS/AutoDockTools_py3) is supposed to translate the old `AutoLigand.py` written in python-2 to python-3, but fumbled it here.
#
#
# ## Resolution
# Raised this issue at the github repo, forked a copy of mine, then modded accordingly and it now works.

# %% [markdown]
# ## Post-Processing
#
# Tabulate the docking scores.

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hsg_mk1/job_1hsg_mk1_script_20251206")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         8                             -10.62
#         5                             -10.57
#         2                             -10.57
#         9                             -10.56
#        10                              -6.886
#         1                              -6.855
#         6                              -6.817
#         7                              -6.764
#         3                              -6.752
#         4                              -5.879

# %% [markdown]
# ## Visualize
#
# Use `nglview` to checkout the best docked pose.
#
# ### TODO
# Directly use `mdanalysis` to compare best docked ligand pose with the experimental one. Currently doing it with `pymol`, but it is better to just compute RMSD on jupyter and visualize both poses with nglview.

# %%
ligand_id = "mk1"
best_pose_id, best_affinity = results[0]
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = testjob[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
view = nv.NGLWidget()
view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="ball+stick", name="Best Ligand Pose")
view.center()
view.display()
view
# Out:
# NGLWidget()

# %% [markdown]
# ## Further Testing
#
# Below is a concise report and a ready test set of **10 experimentally determined protein–ligand complexes (all proteins ≤200 residues)** you can use to validate docking workflows; the list and recommendations are drawn from public structural resources (RCSB PDB and curated datasets).
#
# ---
#
# ### Protein–ligand test set
#
# | **PDB ID** | **Protein (residues)** | **Ligand (type)** | **Method / Resolution** | **Link** |
# |---|---:|---|---|---|
# | **1HEW** | **Hen egg‑white lysozyme (129)** | **Tri‑N‑acetylchitotriose (saccharide)** | X‑ray 1.75 Å | https://www.rcsb.org/structure/1HEW |
# | **1FKB** | **FKBP12 (107)** | **Rapamycin (small molecule)** | X‑ray 1.70 Å | https://www.rcsb.org/structure/1FKB |
# | **1HVR** | **HIV‑1 protease (99 per chain)** | **Nonpeptide cyclic urea inhibitor (small molecule)** | X‑ray 1.80 Å | https://www.rcsb.org/structure/1HVR |
# | **1STP** | **Streptavidin monomer (159)** | **Biotin (small molecule)** | X‑ray 2.60 Å | https://www.rcsb.org/structure/1STP |
# | **1AFK** | **Ribonuclease A (124)** | **Nucleotide analog (small molecule)** | X‑ray 1.70 Å | https://www.rcsb.org/structure/1AFK |
# | **1TU2** | **Apocytochrome F and Plastocyanin Cu Metalloprotein (359)** | **HEC (HEME C ligand molecule)** | NMR  | https://www.rcsb.org/structure/1TU2 |
# | **2UX7** | **Pseudoazurin + Amicyanon loop (122) Mg Metalloprotein @ pH 7.5** | **GOL ( Glycerol ligand molecule)** | X-ray 1.30 Å | https://www.rcsb.org/structure/2UX7 |
# | **1MH1** | **Small G-Protein (183) Cu Metalloprotein** | **GNP ( PHOSPHOAMINOPHOSPHONIC ACID-GUANYLATE ligand molecule)** | X-ray 1.38 Å | https://www.rcsb.org/structure/1MH1 |
# | **2K0F** | **Calmodulin (148)** | **Calmodulin‑binding peptide (peptide ligand)** | NMR (solution) | https://www.rcsb.org/structure/2K0F |
# | **1YCR** | **MDM2 (109)** | **p53 transactivation peptide (peptide ligand)** | X‑ray 2.60 Å | https://www.rcsb.org/structure/1YCR |
# | **1BRS** | **Barnase (110) / Barstar (89)** | **Protein inhibitor (protein–protein complex)** | X‑ray 2.00 Å | https://www.rcsb.org/structure/1BRS |
# | **1STN** | **Staphylococcal nuclease (149)** | **Small‑molecule binding site available** | X‑ray 1.70 Å | https://www.rcsb.org/structure/1STN |
# | **1DFJ** | **Ribonuclease A (124)** | **Bound inhibitor (small/peptide‑like)** | X‑ray 2.50 Å | https://www.rcsb.org/structure/1DFJ |
#
# ### Notes and reasoning
#
# - **Selection criteria:** I prioritized **experimentally validated** entries from public structural repositories and curated datasets, and constrained targets to **≤200 residues** to keep receptors small and tractable for docking and sampling. The RCSB PDB is the primary source for coordinates, experimental method, and resolution. PLBD and curated collections (e.g., PL‑REX) provide complementary lists and affinity/validation metadata useful for benchmarking.
# - **Ligand diversity:** The set intentionally spans **small molecules (biotin, rapamycin, inhibitors), nucleotides, saccharides, peptides, and a protein inhibitor** to exercise different docking challenges: rigid small‑molecule fits, flexible sugar recognition, peptide backbone sampling, and protein–protein interfaces.
# - **Why these are useful:** **Small proteins reduce conformational search space**, making it easier to isolate docking algorithm performance. Peptide and protein‑protein cases test sampling and scoring for larger, flexible interfaces; small‑molecule cases test pose prediction and scoring accuracy.
# - **Practical preparation steps:** Download coordinate files (PDBx/mmCIF) and validation reports from RCSB; extract **chain IDs**, **ligand Chemical Component IDs**, and experimental metadata before preprocessing. Standardize protonation, remove or retain crystallographic waters per your protocol, and handle alternate conformers consistently.
# - **Validation metrics:** For **small molecules** compute heavy‑atom RMSD to deposited ligand coordinates; for **peptides/protein interfaces** use backbone RMSD and interface contact recovery (e.g., fraction of native contacts). Where available, use experimental affinity data from PLBD or curated datasets to correlate docking scores with binding strength.
# - **Next steps I can provide:** I can (a) expand the set with additional small‑molecule complexes, (b) extract **ligand Chemical Component IDs and recommended receptor chain selections** for each PDB entry, or (c) produce a CSV of the table for local use.
#
# **Key takeaway:** This mixed set gives **broad coverage of docking scenarios** while keeping receptors small (≤200 residues), enabling focused benchmarking of sampling and scoring components using experimentally validated structures.

# %% [markdown]
# ## Complex 1HEW_NAG

# %%
import importmonkey
import os
home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hew_nag/experiment/1HEW_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hew_nag/experiment/nag.pdb")

testjob = [{
            "protein_name": "1hew_protein",
            "ligand_name": "nag",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1hew_nag/job_1hew_nag_script_20251208"),
        }]

# Uncomment this to rerun the docking
#run_htvs(testjob, verbose=True)

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hew_nag/job_1hew_nag_script_20251208")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         7                              -7.044
#         3                              -7.016
#         2                              -6.982
#         1                              -6.973
#         5                              -6.964
#         6                              -6.886
#         4                              -6.861
#         8                              -5.453

# %%
ligand_id = "nag"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1hew_nag/experiment/nag_expt.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = testjob[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="hyperball", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# ## Multiple complexes in Parallel
#
# This is best done in script. The environment variables are properly exported that way.
#
# We will now try to dock three complexes concurrently in parallel.
#
# 1. 1fkb_rap
# 2. 1stp_btn
# 3. 1afk_pap

# %%
#/usr/bin/env python
import importmonkey
import os
home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/1FKB_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/rap.pdb")

docking_jobs = [{
            "protein_name": "1fkb_protein",
            "ligand_name": "rap",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251208"),
        }]

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/1STP_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/btn.pdb")

docking_jobs.append({
            "protein_name": "1stp_protein",
            "ligand_name": "btn",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/job_1stp_btn_script_20251208"),
        })


PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/1afk_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/pap.pdb")

docking_jobs.append({
            "protein_name": "1afk_protein",
            "ligand_name": "pap",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/job_1afk_pap_script_20251208"),
        })

# The docking ran in script

# %% [markdown]
# ### 1fkb_rap

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251208")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         1                             -10.88
#         3                             -10.85
#         8                             -10.85
#         5                             -10.84
#         2                             -10.82
#         7                             -10.82
#         6                              -8.043
#         9                              -6.723
#         4                              -6.196
#        10                              -5.753

# %%
ligand_id = "rap"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/experiment/rap_expt.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = docking_jobs[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# The match is nearly perfect here. Excellent docking score implies good experimental match.

# %% [markdown]
# ### 1stp_btn

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/job_1stp_btn_script_20251208")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         5                              -4.242
#         9                              -4.189
#         6                              -4.14
#         4                              -4.071
#         7                              -3.961
#         2                              -3.861
#         3                              -3.77
#        10                              -3.756
#         8                              -3.712
#         1                              -3.422

# %%
ligand_id = "btn"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/experiment/btn_expt.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = docking_jobs[1]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# Docking score is crap. The matching is poor, with the docked ligand lying outside the protein complex. Poor score means poor matching.
#
# ### 1afk_pap

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/job_1afk_pap_script_20251208")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         1                              -5.974
#         2                              -5.945
#         3                              -5.935
#         9                              -5.886
#         8                              -5.482
#         4                              -5.306
#         5                              -5.283
#         7                              -5.154
#         6                              -5.102

# %%
ligand_id = "pap"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/experiment/pap_expt.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = docking_jobs[2]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# Three nearly degenerate-scored docking poses, all poor scores, with poor matching with experiment, but better than the previous case.

# %% [markdown]
# **TODO** Check the two complexes with `AMDock` GUI to see if the results are consistent with the python workflow.
#
# 1. 1stb_btn
# 2. 1afk_pap
#
# ### Report
#
# 1stb_btn docked nearly perfectly in `AMDock`, suggesting that my python workflow needs improvement. Possible improvements are:
# 1. Hacking the default settings of `AMDock` workflow to match the python module better. **Update:** See below for observations.
# 2. Using more cores while running `vina`. **Update:** Doesn't help. See below.
#
# The 1afk_pap complex ran about as poorly with `AMDock` as with the python module.
#
# It may be that docking scores above $-7\; kcal/mol$ are just completely unreliable.

# %% [markdown]
# Reran 1stb_btn serially with all CPUs for `vina`. Got the following results:

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn_rerun/job_1stp_btn_script_20251208")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         6                              -4.15
#         7                              -4.118
#         8                              -4.036
#         9                              -4.025
#         5                              -3.98
#         4                              -3.916
#         3                              -3.853
#        10                              -3.802
#         1                              -3.789
#         2                              -3.534

# %% [markdown]
# It's still crap! So using more CPUs for vina isn't the answer.
#
# Next is to hack `AmDock` better. I compared the amdock log file with log files from the python workflow and saw that a key difference is in the `propka` options. `AMDock` adds extra options that are not added by default in the python workflow.
#
# **Conclusion:** Review the `propka` section in the `AMDock` log files from the docking of `1stp_btn` and compare with `propka` logs from the docking of the same complex using the python workflow. Implement the extra options into the python workflow and rerun. As always, it's the protonation of the ligand where things seem to go sideways...
#
#
# ## Re-test
#
# I implemented the above suggestions on 20251210. Now rerunning `1stp_btn` complex and compare with `AMDock` results.

# %%
import importmonkey
import os
home = os.environ["HOME"]
importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/1STP_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/btn.pdb")

new_1stp_btn = [{
            "protein_name": "1stp_protein",
            "ligand_name": "btn",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/job_1stp_btn_script_20251210"),
        }]

# Uncomment this to rerun the docking
run_htvs(new_1stp_btn, verbose=True)

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/job_1stp_btn_script_20251210")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         2                              -6.936
#         3                              -6.261
#         7                              -6.243
#         4                              -6.026
#         1                              -5.844
#         5                              -5.815
#         8                              -5.288
#        10                              -4.585
#         6                              -4.522
#         9                              -4.446

# %%
ligand_id = "btn"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1stp_btn/btn_expt.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = new_1stp_btn[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# The matching is much, much better for `1stp_btn` at least.
#
# Now, rerunning for `1afk_pap` complex.

# %%
import importmonkey
import os
home = os.environ["HOME"]
importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/1afk_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/pap.pdb")

new_1afk_pap = [{
            "protein_name": "1afk_protein",
            "ligand_name": "pap",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/job_1afk_pap_script_20251210"),
        }]

# Uncomment this to rerun the docking
run_htvs(new_1afk_pap, verbose=False)

# %%
import os
home = os.environ["HOME"]
results_dir = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/job_1afk_pap_script_20251210")
# Scan all log files in the results_dir and print a table of ligand names and their best binding affinities. Use tabulate module for formatting.
from tabulate import tabulate
import re
results = []
for filename in os.listdir(results_dir):
    if not filename.endswith(".log"):
        continue
    log_path = os.path.join(results_dir, filename)
    # extract pose id from filename (try common patterns, fallback to filename stem)
    m = re.search(r'pose[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'site[_-]?(\d+)', filename, re.IGNORECASE) or \
        re.search(r'_(\d+)\.log$', filename)
    pose_id = m.group(1) if m else os.path.splitext(filename)[0]
    with open(log_path, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if line.startswith("-----+"):
                if i + 1 < len(lines):
                    parts = lines[i+1].split()
                    if len(parts) >= 2:
                        try:
                            affinity = float(parts[1])
                        except ValueError:
                            continue
                        results.append((pose_id, affinity))

# sort by affinity in increasing numeric order and format for display
results.sort(key=lambda x: x[1])
table = [(pid, f"{aff:.3f}") for pid, aff in results]
print(tabulate(table, headers=["Pose ID", "Best Binding Affinity (kcal/mol)"]))
# Out:
#   Pose ID    Best Binding Affinity (kcal/mol)
# ---------  ----------------------------------
#         4                              -7.056
#         7                              -6.821
#         6                              -6.793
#         3                              -6.755
#         2                              -6.718
#         5                              -6.487
#         8                              -5.939
#         1                              -5.938
#         9                              -5.895
#        10                              -5.456

# %%
ligand_id = "pap"
best_pose_id, best_affinity = results[0]
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/pap_expt.pdb")
ligand_amdock_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1afk_pap/amdock/1afk_pap_amdock_20251208/results/pap_1afk_expt_out04.pdb")
best_pose_ligand_pdb = os.path.join(results_dir, f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = new_1afk_pap[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose (AmDock)")
view.add_component(ligand_amdock_pose, ext="pdb", default_representation="hyperball", name="Best Ligand Pose (AmDock)")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# The `htvs_amdock` python pipeline agrees well with `AMDock`, but neither agree well with the experimental pose.
#
#
# ## Rerun 1fkb_rap
# Another complex reran with output parsing.

# %%
#/usr/bin/env python
import importmonkey
import os
home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/1FKB_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/rap.pdb")

new_1fkb_rap = [{
            "protein_name": "1fkb_protein",
            "ligand_name": "rap",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251210"),
        }]


# The docking 
#run_htvs(new_1fkb_rap, verbose=False)

# %%
from htvs_amdock import analyze_htvs_results
analyze_htvs_results(new_1fkb_rap)
# Out:
# --- Summary for 1fkb_protein + rap ---
#
# === DOCKING LOG SUMMARY ===
#
# Log file: /home/daneel/gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251210/1fkb_protein_rap_pipeline.log
#
# Detected tools / headers:
#   - propka_header: INFO:PROPKA information:
#   - pdb2pqr: 3.6.1
#   - vina: present
#
# PDB2PQR / structure info:
#   Residues: 107, Atoms: 1021
#
# PROPKA / pKa application:
#   pH applied: 7.4
#   Calculated pI (folded): 8.67
#   ======== PDB2PQR/PROPKA STDOUT ========
#   pKa entries parsed: 36
#   Lowest pKa residues (up to 5):
#          ASP 11A  pKa=1.99
#          ASP 37A  pKa=2.13
#          ASP 79A  pKa=2.71
#         ASP 100A  pKa=2.79
#          C- 107A  pKa=2.89
#   Highest pKa residues (up to 5):
#          ARG 71A  pKa=14.39
#          ARG 42A  pKa=14.31
#          ARG 57A  pKa=13.56
#          ARG 40A  pKa=12.83
#          ARG 13A  pKa=12.46
#
# AutoLigand (Automatic) site search:
#   Rank 1: Volume=241.0, EPV=-0.1949
#   Rank 2: Volume=307.0, EPV=-0.1561
#   Rank 3: Volume=275.0, EPV=-0.1426
#   Rank 4: Volume=303.0, EPV=-0.1413
#   Rank 5: Volume=338.0, EPV=-0.1359
#   Rank 6: Volume=300.0, EPV=-0.1339
#   Rank 7: Volume=311.0, EPV=-0.1330
#   Rank 8: Volume=330.0, EPV=-0.1279
#   Rank 9: Volume=341.0, EPV=-0.1269
#   Rank 10: Volume=339.0, EPV=-0.1249
#
# Affinities found in vina log files:
#
# Aggregated best affinities per pose:
#   Pose ID    Best Affinity (kcal/mol)
# ---------  --------------------------
#         1                     -10.86
#         3                     -10.86
#         9                     -10.86
#         6                     -10.85
#        10                     -10.81
#         5                     -10.8
#         4                      -8.431
#         8                      -6.539
#         7                      -6.199
#         2                      -6.041
#
# --- End of Summary for 1fkb_protein + rap ---

# %%
ligand_id = "rap"
best_pose_id = 1
ligand_expt_pose = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/rap_expt.pdb")
best_pose_ligand_pdb = os.path.join(os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251210"), f"{ligand_id}_pose_site{best_pose_id}.pdb")
protein_pdb = new_1fkb_rap[0]["protein_pdb"]
#use nglview to visualize the best pose
import nglview as nv
from IPython.display import display, Image
view = nv.NGLWidget()

view.add_component(protein_pdb, ext="pdb", default_representation="cartoon", name="Protein")
view.add_component(ligand_expt_pose, ext="pdb", default_representation="licorice", name="Experimental Ligand")
view.add_component(best_pose_ligand_pdb, ext="pdb", default_representation="hyperball", name="Best Ligand Pose")
view.center()
view
# Out:
# NGLWidget()

# %% [markdown]
# ## Report (20251210)
#
# So far so good. `AMDock` and `htvs_amdock` are more-or-less in agreement for simple proteins complexed with ligands.
#
# **TODO**
# 1. Proteins with metals (check `AMDock` options and implement modifications in `htvs_amdock`). Try the metalloprotein complexes from the table above.
#
#    * Look at AMDock source code files `input_tab.py` and the `Fix_PQR` class in `tools.py`
#    * Look at the code involving the `Keep Metals in Receptors:` option.
#    * The idea is simple (in principle). `PDB2PQR/PROPKA` removes all metals from the input pdb while protonating. So the protonated PDB needs proper `TER`, followed by simply copy-pasting the metal entries from the original PDB. Only then can `prepare_receptor4` be run with `-U, -p XXX, -C` flags
#
#
# 2. `Autodock4Zn` with Zinc fingers
# 3. Protein-peptide complexes
# 4. Off target (protein-protein) docking
# 5. Possibly docking peptides/ligands with DNA segments (optional).

# %% [markdown]
# ### 1MH1_GNP First metalloprotein-ligand docking

# %%
import importmonkey
import os

home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1mh1_gnp/1MH1_protein.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1mh1_gnp/gnp.pdb")

metalloprotein_job = [{
            "protein_name": "1mh1_protein",
            "ligand_name": "gnp",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1mh1_gnp/job_1mh1_gnp_script_20251212"),
            "keep_metals": True,
        }]

# Uncomment this to rerun the docking
run_htvs(metalloprotein_job, verbose=True)
# Out:
# --- Starting HTVS Parallel Execution ---
# Vina internal cores per job: 12
# Maximum simultaneous HTVS jobs: 1
# Total jobs requested: 1
# Running pdb2pqr: pdb2pqr --keep-chain --noopt --ff=AMBER --with-ph 7.4 /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/1MH1_protein.pdb /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/job_1mh1_gnp_script_20251212/1mh1_protein_h.pqr --nodebump -k --protonate-all --titration-state-method=propka --pH 7.4 -f /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/job_1mh1_gnp_script_20251212/1mh1_protein_h_h.pdb
# [job_1mh1_gnp_script_20251212] Merged 1 metal ions into PQR.
# /usr/local/miniforge3/envs/htvs/lib/python3.12/site-packages/openbabel/__init__.py:14: UserWarning: "import openbabel" is deprecated, instead use "from openbabel import openbabel"
#   warnings.warn('"import openbabel" is deprecated, instead use "from openbabel import openbabel"')
# [job_1mh1_gnp_script_20251212] Converted PQR -> PDB using pybel: /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/job_1mh1_gnp_script_20251212/1mh1_protein_h.pdb
# [job_1mh1_gnp_script_20251212] Executing: prepare_receptor4 -r 1mh1_protein_h.pdb -C -p MG -U nphs_lps_waters_nonstdres_deleteAltB -o 1mh1_protein_h.pdbqt
#  charge : 13.354
#  radius : 0.2943
#  charge : 12.55
#  radius : -0.01
#  charge : 13.483
#  radius : 0.6163
#  charge : 14.7
#  radius : -0.5722
#  charge : 13.675
#  radius : 0.1642
#  charge : 12.258
#  radius : 0.0895
#  charge : 11.791
#  radius : 0.0895
#  charge : 12.783
#  radius : 0.1642
#  charge : 14.133
#  radius : 0.1642
#  charge : 14.441
#  radius : -0.2548
#  charge : 14.227
#  radius : -0.0266
#  charge : 12.903
#  radius : 0.5896
#  charge : 12.668
#  radius : -0.5748
#  charge : 15.437
#  radius : -0.007
#  charge : 16.473
#  radius : 0.0189
#  charge : 15.68
#  radius : 0.0192
#  charge : 14.174
#  radius : 0.0641
#  charge : 15.24
#  radius : 0.0253
#  charge : 15.756
#  radius : 0.0253
#  charge : 17.18
#  radius : 0.0213
#  charge : 16.875
#  radius : 0.0213
#  charge : 15.479
#  radius : 0.0391
#  charge : 16.126
#  radius : 0.0391
#  charge : 12.939
#  radius : -0.4157
#  charge : 13.759
#  radius : -0.0249
#  charge : 13.54
#  radius : 0.5973
#  charge : 12.551
#  radius : -0.5679
#  charge : 13.368
#  radius : 0.2117
#  charge : 13.038
#  radius : -0.6546
#  charge : 12.342
#  radius : 0.2719
#  charge : 14.715
#  radius : 0.0843
#  charge : 12.579
#  radius : 0.0352
#  charge : 14.134
#  radius : 0.0352
#  charge : 13.125
#  radius : 0.4275
#  charge : 12.09
#  radius : -0.4157
#  charge : 10.79
#  radius : -0.0031
#  charge : 11.104
#  radius : 0.5973
#  charge : 11.751
#  radius : -0.5679
#  charge : 9.86
#  radius : -0.0036
#  charge : 8.451
#  radius : -0.0645
#  charge : 7.433
#  radius : 0.6951
#  charge : 6.468
#  radius : -0.9407
#  charge : 7.48
#  radius : -0.6086
#  charge : 12.985
#  radius : 0.2719
#  charge : 10.378
#  radius : 0.085
#  charge : 9.817
#  radius : 0.0171
#  charge : 10.171
#  radius : 0.0171
#  charge : 8.491
#  radius : 0.0352
#  charge : 8.18
#  radius : 0.0352
#  charge : 5.741
#  radius : 0.4251
#  charge : 6.484
#  radius : 0.4251
#  charge : 10.596
#  radius : -0.4157
#  charge : 10.815
#  radius : 0.0337
#  charge : 9.8
#  radius : 0.5973
#  charge : 8.562
#  radius : -0.5679
#  charge : 10.684
#  radius : -0.1825
#  charge : 10.065
#  radius : 0.2719
#  charge : 11.732
#  radius : 0.0823
#  charge : 10.784
#  radius : 0.0603
#  charge : 11.395
#  radius : 0.0192
#  charge : 4.599
#  radius : 0.0641
#  charge : 5.137
#  radius : 0.0253
#  charge : 6.098
#  radius : 0.0253
#  charge : 6.469
#  radius : 0.0213
#  charge : 7.395
#  radius : 0.0213
#  charge : 5.613
#  radius : 0.0391
#  charge : 6.603
#  radius : 0.0391
#  charge : 2.555
#  radius : -0.2802
#  charge : 1.229
#  radius : -0.1336
#  charge : 1.308
#  radius : 0.6631
#  charge : 0.297
#  radius : -0.7697
#  charge : 1.085
#  radius : -0.0543
#  charge : 2.384
#  radius : 0.0466
#  charge : 3.305
#  radius : 0.0434
#  charge : 2.303
#  radius : -0.7697
#  charge : 0.537
#  radius : 0.0776
#  charge : 0.897
#  radius : 0.0381
#  charge : 0.313
#  radius : 0.0381
#  charge : 2.796
#  radius : 0.0172
#  charge : 2.185
#  radius : 0.0172
#  charge : 4.166
#  radius : 0.0331
#  charge : 3.519
#  radius : 0.0331
#  charge : 1
#  radius : 10.54
# [job_1mh1_gnp_script_20251212] Prepare_Receptor4 completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: prepare_ligand4 -l /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/gnp.pdb -o gnp.pdbqt
# [job_1mh1_gnp_script_20251212] Prepare_Ligand4 completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: autogrid4 -p grid.gpf -l grid.glg
# [job_1mh1_gnp_script_20251212] AutoGrid4 completed successfully.
# [job_1mh1_gnp_script_20251212] --- Running AutoLigand (Automatic Mode) ---
# [job_1mh1_gnp_script_20251212] AutoLigand command executed. Parsing generated FILL files...
# [job_1mh1_gnp_script_20251212] AutoLigand identified 7 binding site(s).
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 5.49811111111112 --center_y 44.92277777777769 --center_z 16.4458888888889 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site1.pdbqt > vina_site1.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 1) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 3.2425555555555565 --center_y 42.456111111111035 --center_z 16.590333333333344 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site2.pdbqt > vina_site2.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 2) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 5.820333333333343 --center_y 44.74499999999991 --center_z 17.690333333333346 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site3.pdbqt > vina_site3.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 3) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 3.242555555555555 --center_y 42.078333333333255 --center_z 16.390333333333345 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site4.pdbqt > vina_site4.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 4) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 5.2425555555555645 --center_y 45.70055555555547 --center_z 16.35700000000001 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site5.pdbqt > vina_site5.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 5) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 6.42033333333334 --center_y 44.54499999999991 --center_z 17.112555555555566 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site6.pdbqt > vina_site6.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 6) completed successfully.
# [job_1mh1_gnp_script_20251212] Executing: vina --receptor 1mh1_protein_h.pdbqt --ligand gnp.pdbqt --center_x 9.131444444444439 --center_y 32.44499999999996 --center_z -4.120777777777777 --size_x 30 --size_y 30 --size_z 30 --cpu 12 --out gnp_pose_site7.pdbqt > vina_site7.log 2>&1
# [job_1mh1_gnp_script_20251212] AutoDock Vina (Site 7) completed successfully.
# [job_1mh1_gnp_script_20251212] Docking completed successfully.
#
# *** Docking for 1mh1_protein + gnp Complete (Total sites docked: 7). ***
#
# --- HTVS Finished ---
# Summary: 1/1 pairs successfully processed.

# %%
from htvs_amdock import analyze_htvs_results
analyze_htvs_results(metalloprotein_job)
# Out:
# --- Summary for 1mh1_protein + gnp ---
#
# === DOCKING LOG SUMMARY ===
#
# Log file: /home/daneel/gitrepos/gromacs_sims/htvs/1mh1_gnp/job_1mh1_gnp_script_20251212/1mh1_protein_gnp_pipeline.log
#
# Detected tools / headers:
#   - propka_header: INFO:PROPKA information:
#   - pdb2pqr: 3.6.1
#   - vina: present
#
# PDB2PQR / structure info:
#   Residues: 184, Atoms: 1379
#   Unknown residue/component definitions: MG.
#   Missing atoms detected: 111 (see warnings)
#
# PROPKA / pKa application:
#   pH applied: 7.4
#   Calculated pI (folded): 6.79
#   ======== PDB2PQR/PROPKA STDOUT ========
#   pKa entries parsed: 60
#   Lowest pKa residues (up to 5):
#          ASP 47A  pKa=2.22
#          ASP 65A  pKa=2.39
#         ASP 122A  pKa=2.50
#         GLU 148A  pKa=2.94
#          C- 181A  pKa=3.33
#   Highest pKa residues (up to 5):
#          ARG 94A  pKa=15.13
#         ARG 174A  pKa=15.11
#          TYR 72A  pKa=14.76
#         TYR 154A  pKa=14.43
#         ARG 120A  pKa=13.88
#
# AutoLigand (Automatic) site search:
#   Rank 1: Volume=260.0, EPV=-0.2362
#   Rank 2: Volume=301.0, EPV=-0.2149
#   Rank 3: Volume=286.0, EPV=-0.2126
#   Rank 4: Volume=312.0, EPV=-0.2074
#   Rank 5: Volume=297.0, EPV=-0.1994
#   Rank 6: Volume=294.0, EPV=-0.1978
#   Rank 7: Volume=275.0, EPV=-0.1623
#
# Affinities found in vina log files:
#
# Aggregated best affinities per pose:
#   Pose ID    Best Affinity (kcal/mol)
# ---------  --------------------------
#         4                      -9.223
#         5                      -9.164
#         1                      -8.828
#         6                      -8.441
#         3                      -8.111
#         2                      -7.521
#         7                      -5.856
#
# --- End of Summary for 1mh1_protein + gnp ---

# %% [markdown]
# ### Report (20251213)
#
# So this particular metalloprotein complex does dock after a lot of painful vibe coding by trial and error, but the docking is inferior to `AMDock`.
# The most likely culprit is the `-C` option executed while calling `prepare_receptor4`, which preserves all input charges ie do not add new charges. This overrides the default option of adding gasteiger charges and messes up the charges of the atoms.
#
# However, eliminating this option results in `prepare_receptor4` crashing, suggesting that the bloody metal entries are still being malformatted somehow.
#
# Will have to vibe code this further.
#
#
# Meanwhile, the new code still works on non-metal proteins, as seen below.

# %%
#/usr/bin/env python
import importmonkey
import os
home = os.environ["HOME"]

importmonkey.add_path(os.path.join(home, "gitrepos/gromacs_sims/scripts"))
from htvs_amdock import run_htvs

PROTEIN_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/1FKB_expt.pdb")
LIGAND_PDB = os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/rap.pdb")

new_1fkb_rap = [{
            "protein_name": "1fkb_protein",
            "ligand_name": "rap",
            "protein_pdb": PROTEIN_PDB,
            "ligand_pdb": LIGAND_PDB,
            "working_dir": os.path.join(home, "gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251213"),
        }]


# The docking 
run_htvs(new_1fkb_rap, verbose=False)
# Out:
# /usr/local/miniforge3/envs/htvs/lib/python3.12/site-packages/openbabel/__init__.py:14: UserWarning: "import openbabel" is deprecated, instead use "from openbabel import openbabel"
#   warnings.warn('"import openbabel" is deprecated, instead use "from openbabel import openbabel"')
#  charge : 8.513
#  radius : 0.2943
#  charge : 7.474
#  radius : -0.01
#  charge : 7.981
#  radius : 0.6163
#  charge : 9.187
#  radius : -0.5722
#  charge : 9.34
#  radius : 0.1642
#  charge : 7.226
#  radius : 0.0895
#  charge : 6.664
#  radius : 0.0895
#  charge : 8.206
#  radius : 0.1642
#  charge : 8.746
#  radius : 0.1642
#  charge : 7.058
#  radius : -0.4157
#  charge : 7.337
#  radius : -0.0875
#  charge : 6.634
#  radius : 0.5973
#  charge : 5.471
#  radius : -0.5679
#  charge : 6.904
#  radius : 0.2985
#  charge : 5.431
#  radius : -0.3192
#  charge : 7.235
#  radius : -0.3192
#  charge : 6.085
#  radius : 0.2719
#  charge : 8.311
#  radius : 0.0969
#  charge : 7.441
#  radius : -0.0297
#  charge : 4.951
#  radius : 0.0791
#  charge : 5.355
#  radius : 0.0791
#  charge : 5.027
#  radius : 0.0791
#  charge : 6.825
#  radius : 0.0791
#  charge : 8.227
#  radius : 0.0791
#  charge : 6.866
#  radius : 0.0791
#  charge : 7.387
#  radius : -0.4157
#  charge : 6.837
#  radius : -0.0031
#  charge : 6.705
#  radius : 0.5973
#  charge : 7.648
#  radius : -0.5679
#  charge : 7.821
#  radius : 0.0882
#  charge : 10.807
#  radius : 0.0186
#  charge : 10.777
#  radius : 0.0186
#  charge : 9.698
#  radius : 0.0186
#  charge : 5.28
#  radius : -0.4157
#  charge : 4.303
#  radius : -0.0249
#  charge : 3.023
#  radius : 0.5973
#  charge : 3.08
#  radius : -0.5679
#  charge : 4.74
#  radius : 0.2117
#  charge : 6.14
#  radius : -0.6546
#  charge : 5.307
#  radius : 0.2719
#  charge : 4.118
#  radius : 0.0843
#  charge : 4.506
#  radius : 0.0352
#  charge : 4.278
#  radius : 0.0352
#  charge : 6.545
#  radius : 0.4275
#  charge : 1.861
#  radius : -0.2548
#  charge : 0.615
#  radius : -0.0266
#  charge : 0.137
#  radius : 0.5896
#  charge : 0.374
#  radius : -0.5748
#  charge : -0.331
#  radius : -0.007
#  charge : 0.188
#  radius : 0.0189
#  charge : 1.687
#  radius : 0.0192
#  charge : 0.665
#  radius : 0.0641
#  charge : -1.27
#  radius : 0.0253
#  charge : -0.291
#  radius : 0.0253
#  charge : -0.048
#  radius : 0.0213
#  charge : -0.136
#  radius : 0.0213
#  charge : 2.192
#  radius : 0.0391
#  charge : 1.97
#  radius : 0.0391
#  charge : -0.49
#  radius : -0.4157
#  charge : -1.16
#  radius : -0.0252
#  charge : -2.571
#  radius : 0.5973
#  charge : -2.922
#  radius : -0.5679
#  charge : -0.454
#  radius : 0.2719
#  charge : -0.673
#  radius : 0.0698
#  charge : -1.191
#  radius : 0.0698
#  charge : -3.43
#  radius : -0.5163
#  charge : -4.802
#  radius : 0.0381
#  charge : -5.692
#  radius : 0.5366
#  charge : -6.86
#  radius : -0.5819
#  charge : -5.442
#  radius : -0.0303
#  charge : -5.797
#  radius : 0.7994
#  charge : -5.552
#  radius : -0.8014
#  charge : -6.329
#  radius : -0.8014
#  charge : -3.067
#  radius : 0.2936
#  charge : -4.763
#  radius : 0.088
#  charge : -6.29
#  radius : -0.0122
#  charge : -4.808
#  radius : -0.0122
#  charge : -5.217
#  radius : -0.4157
#  charge : -5.971
#  radius : -0.0252
#  charge : -7.21
#  radius : 0.5973
#  charge : -8.056
#  radius : -0.5679
#  charge : -4.259
#  radius : 0.2719
#  charge : -5.357
#  radius : 0.0698
#  charge : -6.25
#  radius : 0.0698
#  charge : -7.349
#  radius : -0.3479
#  charge : -8.541
#  radius : -0.2637
#  charge : -8.22
#  radius : 0.7341
#  charge : -8.893
#  radius : -0.5894
#  charge : -9.383
#  radius : -0.0007
#  charge : -10.001
#  radius : 0.039
#  charge : -11.364
#  radius : 0.0486
#  charge : -12.166
#  radius : -0.5295
#  charge : -13.138
#  radius : 0.8076
#  charge : -13.398
#  radius : -0.8627
#  charge : -13.879
#  radius : -0.8627
#  charge : -6.511
#  radius : 0.2747
#  charge : -9.101
#  radius : 0.156
#  charge : -8.795
#  radius : 0.0327
#  charge : -10.119
#  radius : 0.0327
#  charge : -10.116
#  radius : 0.0285
#  charge : -9.464
#  radius : 0.0285
#  charge : -11.241
#  radius : 0.0687
#  radius : 0.3456
#  charge : 6.221
#  radius : 0.4478
#  charge : 5.051
#  radius : 0.4478
#  charge : 2.614
#  radius : 0.4478
#  charge : 3.027
#  radius : 0.4478
#  charge : 7.877
#  radius : -0.4157
#  charge : 7.752
#  radius : -0.0252
#  charge : 7.242
#  radius : 0.5973
#  charge : 6.578
#  radius : -0.5679
#  charge : 8.779
#  radius : 0.2719
#  charge : 7.124
#  radius : 0.0698
#  charge : 8.658
#  radius : 0.0698
#  charge : 7.565
#  radius : -0.4157
#  charge : 7.036
#  radius : -0.0275
#  charge : 5.604
#  radius : 0.5973
#  charge : 4.776
#  radius : -0.5679
#  charge : 7.798
#  radius : -0.005
#  charge : 8.883
#  radius : -0.1415
#  charge : 9.922
#  radius : -0.1638
#  charge : 8.981
#  radius : 0.1243
#  charge : 10.155
#  radius : 0.138
#  charge : 8.28
#  radius : -0.2387
#  charge : 10.664
#  radius : -0.3418
#  charge : 10.673
#  radius : -0.2601
#  charge : 8.796
#  radius : -0.1972
#  charge : 9.975
#  radius : -0.1134
#  charge : 8.216
#  radius : 0.2719
#  charge : 7.045
#  radius : 0.1123
#  charge : 8.246
#  radius : 0.0339
#  charge : 7.177
#  radius : 0.0339
#  charge : 10.048
#  radius : 0.2062
#  charge : 11.534
#  radius : 0.3412
#  charge : 7.415
#  radius : 0.17
#  charge : 11.533
#  radius : 0.1572
#  charge : 8.298
#  radius : 0.1447
#  charge : 10.327
#  radius : 0.1417
#  charge : 5.269
#  radius : -0.5163
#  charge : 3.898
#  radius : 0.0397
#  charge : 2.943
#  radius : 0.5366
#  charge : 1.87
#  radius : -0.5819
#  charge : 3.809
#  radius : 0.056
#  charge : 4.51
#  radius : 0.0136
#  charge : 3.705
#  radius : 0.8054
#  charge : 3.381
#  radius : -0.8188
#  charge : 3.398
#  radius : -0.8188
#  charge : 6.068
#  radius : 0.2936
#  charge : 3.591
#  radius : 0.1105
#  charge : 4.194
#  radius : -0.0173
#  charge : 2.838
#  radius : -0.0173
#  charge : 5.347
#  radius : -0.0425
#  charge : 4.702
#  radius : -0.0425
#  charge : 3.335
#  radius : -0.5163
#  charge : 2.52
#  radius : 0.0397
#  charge : 2.638
#  radius : 0.5366
#  charge : 1.668
#  radius : -0.5819
#  charge : 2.872
#  radius : 0.056
#  charge : 2.265
#  radius : 0.0136
#  charge : 2.517
#  radius : 0.8054
#  charge : 2.791
#  radius : -0.8188
#  charge : 2.403
#  radius : -0.8188
#  charge : 4.249
#  radius : 0.2936
#  charge : 1.54
#  radius : 0.1105
#  charge : 3.818
#  radius : -0.0173
#  charge : 2.436
#  radius : -0.0173
#  charge : 1.269
#  radius : -0.0425
#  charge : 2.614
#  radius : -0.0425
#  charge : 3.819
#  radius : -0.4157
#  charge : 4.072
#  radius : -0.0252
#  charge : 3.329
#  radius : 0.5973
#  charge : 2.556
#  radius : -0.5679
#  charge : 4.545
#  radius : 0.2719
#  charge : 3.788
#  radius : 0.0698
#  charge : 5.065
#  radius : 0.0698
#  charge : 3.508
#  radius : -0.4157
#  charge : 2.893
#  radius : -0.0875
#  charge : 1.369
#  radius : 0.5973
#  charge : 0.671
#  radius : -0.5679
#  charge : 3.586
#  radius : 0.2985
#  charge : 2.892
#  radius : -0.3192
#  charge : 5.07
#  radius : -0.3192
#  charge : 4.11
#  radius : 0.2719
#  charge : 3.112
#  radius : 0.0969
#  charge : 3.502
#  radius : -0.0297
#  charge : 3.423
#  radius : 0.0791
#  charge : 2.825
#  radius : 0.0791
#  charge : 1.976
#  radius : 0.0791
#  charge : 5.593
#  radius : 0.0791
#  charge : 5.155
#  radius : 0.0791
#  charge : 5.389
#  radius : 0.0791
#  charge : 0.822
#  radius : -0.4157
#  charge : -0.611
#  radius : 0.0337
#  charge : -1.337
#  radius : 0.5973
#  charge : -2.531
#  radius : -0.5679
#  charge : -0.902
#  radius : -0.1825
#  charge : 1.513
#  radius : 0.2719
#  charge : -1.025
#  radius : 0.0823
#  charge : -0.497
#  radius : 0.0603
#  charge : -1.891
#  radius : 0.0603
#  charge : -0.511
#  radius : 0.0603
#  charge : -0.648
#  radius : -0.4157
#  charge : -1.328
#  radius : -0.0031
#  charge : -1.037
#  radius : 0.5973
#  charge : -1.318
#  radius : -0.5679
#  charge : -1.029
#  radius : -0.0036
#  charge : 0.436
#  radius : -0.0645
#  charge : 0.752
#  radius : 0.6951
#  charge : 1.129
#  radius : -0.9407
#  charge : 0.694
#  radius : -0.6086
#  charge : 0.33
#  radius : 0.2719
#  charge : -2.323
#  radius : 0.085
#  charge : -1.452
#  radius : 0.0171
#  charge : -1.427
#  radius : 0.0171
#  charge : 0.895
#  radius : 0.0352
#  charge : 0.814
#  radius : 0.0352
#  charge : 1.368
#  radius : 0.4251
#  charge : 1.175
#  radius : 0.4251
#  charge : -0.469
#  radius : -0.4157
#  charge : -0.162
#  radius : -0.0237
#  charge : -1.229
#  radius : 0.5973
#  charge : -1.779
#  radius : -0.5679
#  charge : 1.233
#  radius : 0.0342
#  charge : 2.396
#  radius : 0.0018
#  charge : 3.979
#  radius : -0.2737
#  charge : 4.016
#  radius : -0.0536
#  charge : -0.281
#  radius : 0.2719
#  charge : -0.22
#  radius : 0.088
#  charge : 1.329
#  radius : 0.0241
#  charge : 1.336
#  radius : 0.0241
#  charge : 2.364
#  radius : 0.044
#  charge : 2.258
#  radius : 0.044
#  charge : 4.676
#  radius : 0.0684
#  charge : 4.286
#  radius : 0.0684
#  charge : 3.108
#  radius : 0.0684
#  charge : -1.551
#  radius : -0.4157
#  charge : -2.428
#  radius : -0.0249
#  charge : -1.664
#  radius : 0.5973
#  charge : -0.508
#  radius : -0.5679
#  charge : -3.519
#  radius : 0.2117
#  charge : -3.109
#  radius : -0.6546
#  charge : -1.142
#  radius : 0.2719
#  charge : -2.906
#  radius : 0.0843
#  charge : -4.118
#  radius : 0.0352
#  charge : -4.114
#  radius : 0.0352
#  charge : -2.084
#  radius : 0.4275
#  charge : -2.286
#  radius : -0.4157
#  charge : -1.624
#  radius : -0.0875
#  charge : -1.15
#  radius : -0.0011
#  charge : 16.401
#  radius : -0.1906
#  charge : 16.916
#  radius : -0.1906
#  charge : 15.897
#  radius : -0.2341
#  charge : 16.422
#  radius : -0.2341
#  charge : 15.919
#  radius : 0.3226
#  charge : 15.452
#  radius : -0.5579
#  charge : 15.791
#  radius : 0.2719
#  charge : 15.521
#  radius : 0.0876
#  charge : 17.847
#  radius : 0.0295
#  charge : 17.842
#  radius : 0.0295
#  charge : 16.415
#  radius : 0.1699
#  charge : 17.287
#  radius : 0.1699
#  charge : 15.526
#  radius : 0.1656
#  charge : 16.429
#  radius : 0.1656
#  charge : 15.563
#  radius : 0.3992
#  charge : 16.257
#  radius : -0.4157
#  charge : 16.424
#  radius : -0.0252
#  charge : 17.852
#  radius : 0.5973
#  charge : 18.777
#  radius : -0.5679
#  charge : 15.864
#  radius : 0.2719
#  charge : 15.983
#  radius : 0.0698
#  charge : 15.892
#  radius : 0.0698
#  charge : 18.054
#  radius : -0.4157
#  charge : 19.371
#  radius : 0.0337
#  charge : 20.325
#  radius : 0.5973
#  charge : 21.525
#  radius : -0.5679
#  charge : 19.254
#  radius : -0.1825
#  charge : 17.251
#  radius : 0.2719
#  charge : 19.748
#  radius : 0.0823
#  charge : 18.36
#  radius : 0.0603
#  charge : 19.974
#  radius : 0.0603
#  charge : 19.348
#  radius : 0.0603
#  charge : 19.838
#  radius : -0.4157
#  charge : 20.683
#  radius : -0.0389
#  charge : 21.166
#  radius : 0.5973
#  charge : 22.257
#  radius : -0.5679
#  charge : 19.972
#  radius : 0.3654
#  charge : 18.526
#  radius : -0.2438
#  charge : 20.063
#  radius : -0.6761
#  charge : 18.811
#  radius : 0.2719
#  charge : 21.493
#  radius : 0.1007
#  charge : 20.445
#  radius : 0.0043
#  charge : 20.582
#  radius : 0.4102
#  charge : 18.125
#  radius : 0.0642
#  charge : 18.5
#  radius : 0.0642
#  charge : 17.995
#  radius : 0.0642
#  charge : 20.331
#  radius : -0.4157
#  charge : 20.663
#  radius : -0.0252
#  charge : 20.429
#  radius : 0.5973
#  charge : 19.804
#  radius : -0.5679
#  charge : 19.447
#  radius : 0.2719
#  charge : 20.082
#  radius : 0.0698
#  charge : 21.622
#  radius : 0.0698
#  charge : 20.894
#  radius : -0.4157
#  charge : 20.776
#  radius : 0.0188
#  charge : 22.211
#  radius : 0.5973
#  charge : 22.884
#  radius : -0.5679
#  charge : 20.021
#  radius : -0.0462
#  charge : 19.827
#  radius : -0.0266
#  charge : 20.513
#  radius : 0.1292
#  charge : 19.044
#  radius : -0.3811
#  charge : 19.247
#  radius : 0.2057
#  charge : 20.12
#  radius : -0.5727
#  charge : 21.345
#  radius : 0.2719
#  charge : 20.377
#  radius : 0.0881
#  charge : 19.123
#  radius : 0.0402
#  charge : 20.539
#  radius : 0.0402
#  charge : 18.416
#  radius : 0.3649
#  charge : 21.166
#  radius : 0.1147
#  charge : 18.814
#  radius : 0.1392
#  charge : 22.713
#  radius : -0.2548
#  charge : 24.124
#  radius : -0.0266
#  charge : 24.776
#  radius : 0.5896
#  charge : 24.228
#  radius : -0.5748
#  charge : 24.098
#  radius : -0.007
#  charge : 22.687
#  radius : 0.0189
#  charge : 21.918
#  radius : 0.0192
#  charge : 24.653
#  radius : 0.0641
#  charge : 24.755
#  radius : 0.0253
#  charge : 24.311
#  radius : 0.0253
#  charge : 22.555
#  radius : 0.0213
#  charge : 22.476
#  radius : 0.0213
#  charge : 20.994
#  radius : 0.0391
#  charge : 21.908
#  radius : 0.0391
#  charge : 25.885
#  radius : -0.4157
#  charge : 26.645
#  radius : -0.0252
#  charge : 26.184
#  radius : 0.5973
#  charge : 26.951
#  radius : -0.5679
#  charge : 26.151
#  radius : 0.2719
#  charge : 27.63
#  radius : 0.0698
#  charge : 26.58
#  radius : 0.0698
#  charge : 24.961
#  radius : -0.4157
#  charge : 24.404
#  radius : -0.0597
#  charge : 23.957
#  radius : 0.5973
#  charge : 24.409
#  radius : -0.5679
#  charge : 23.227
#  radius : 0.1303
#  charge : 23.621
#  radius : -0.043
#  charge : 22.728
#  radius : -0.3204
#  charge : 22.505
#  radius : -0.066
#  charge : 24.462
#  radius : 0.2719
#  charge : 25.154
#  radius : 0.0869
#  charge : 22.486
#  radius : 0.0187
#  charge : 24.343
#  radius : 0.0236
#  charge : 24.038
#  radius : 0.0236
#  charge : 21.929
#  radius : 0.0882
#  charge : 22.478
#  radius : 0.0882
#  charge : 23.45
#  radius : 0.0882
#  charge : 22.114
#  radius : 0.0186
#  charge : 22.908
#  radius : 0.0186
#  charge : 21.814
#  radius : 0.0186
#  charge : 23.074
#  radius : -0.4157
#  charge : 22.478
#  radius : -0.0597
#  charge : 23.031
#  radius : 0.5973
#  charge : 22.882
#  radius : -0.5679
#  charge : 20.926
#  radius : 0.1303
#  charge : 20.279
#  radius : -0.043
#  charge : 20.291
#  radius : -0.3204
#  charge : 20.549
#  radius : -0.066
#  charge : 22.855
#  radius : 0.2719
#  charge : 22.855
#  radius : 0.0869
#  charge : 20.682
#  radius : 0.0187
#  charge : 20.576
#  radius : 0.0236
#  charge : 19.275
#  radius : 0.0236
#  charge : 19.312
#  radius : 0.0882
#  charge : 20.719
#  radius : 0.0882
#  charge : 20.411
#  radius : 0.0882
#  charge : 21.532
#  radius : 0.0186
#  charge : 20.074
#  radius : 0.0186
#  charge : 20.22
#  radius : 0.0186
#  charge : 23.669
#  radius : -0.2548
#  charge : 24.185
#  radius : -0.0266
#  charge : 23.054
#  radius : 0.5896
#  charge : 21.91
#  radius : -0.5748
#  charge : 24.953
#  radius : -0.007
#  charge : 24.973
#  radius : 0.0189
#  charge : 23.767
#  radius : 0.0192
#  charge : 24.793
#  radius : 0.0641
#  charge : 24.5
#  radius : 0.0253
#  charge : 25.898
#  radius : 0.0253
#  charge : 24.886
#  radius : 0.0213
#  charge : 25.809
#  radius : 0.0213
#  charge : 22.936
#  radius : 0.0391
#  charge : 23.889
#  radius : 0.0391
#  charge : 23.322
#  radius : -0.2548
#  charge : 22.401
#  radius : -0.0266
#  charge : 21.956
#  radius : 0.5896
#  charge : 22.705
#  radius : -0.5748
#  charge : 23.264
#  radius : -0.007
#  charge : 24.167
#  radius : 0.0189
#  charge : 24.56
#  radius : 0.0192
#  charge : 21.607
#  radius : 0.0641
#  charge : 23.797
#  radius : 0.0253
#  charge : 22.704
#  radius : 0.0253
#  charge : 24.949
#  radius : 0.0213
#  charge : 23.674
#  radius : 0.0213
#  charge : 25.283
#  radius : 0.0391
#  charge : 24.872
#  radius : 0.0391
#  charge : 20.674
#  radius : -0.4157
#  charge : 20.078
#  radius : 0.0188
#  charge : 20.149
#  radius : 0.5973
#  charge : 20.308
#  radius : -0.5679
#  charge : 20.767
#  radius : -0.0462
#  charge : 19.99
#  radius : -0.0266
#  charge : 18.81
#  radius : 0.1292
#  charge : 20.281
#  radius : -0.3811
#  charge : 19.339
#  radius : 0.2057
#  charge : 18.464
#  radius : -0.5727
#  charge : 20.147
#  radius : 0.2719
#  charge : 19.103
#  radius : 0.0881
#  charge : 20.867
#  radius : 0.0402
#  charge : 21.67
#  radius : 0.0402
#  charge : 21.071
#  radius : 0.3649
#  charge : 18.357
#  radius : 0.1147
#  charge : 19.292
#  radius : 0.1392
#  charge : 19.985
#  radius : -0.4157
#  charge : 19.964
#  radius : 0.0337
#  charge : 18.548
#  radius : 0.5973
#  charge : 17.59
#  radius : -0.5679
#  charge : 20.567
#  radius : -0.1825
#  charge : 19.881
#  radius : 0.2719
#  charge : 20.517
#  radius : 0.0823
#  charge : 21.413
#  radius : 0.0603
#  charge : 19.918
#  radius : 0.0603
#  charge : 20.763
#  radius : 0.0603
#  charge : 18.404
#  radius : -0.4157
#  charge : 17.217
#  radius : -0.0389
#  charge : 17.339
#  radius : 0.5973
#  charge : 18.406
#  radius : -0.5679
#  charge : 17.057
#  radius : 0.3654
#  charge : 15.861
#  radius : -0.2438
#  charge : 16.899
#  radius : -0.6761
#  charge : 19.234
#  radius : 0.2719
#  charge : 16.415
#  radius : 0.1007
#  charge : 17.907
#  radius : 0.0043
#  charge : 16.929
#  radius : 0.4102
#  charge : 15.769
#  radius : 0.0642
#  charge : 15.027
#  radius : 0.0642
#  charge : 16.011
#  radius : 0.0642
#  charge : 16.273
#  radius : -0.4157
#  charge : 16.316
#  radius : -0.0518
#  charge : 15.408
#  radius : 0.5973
#  charge : 14.331
#  radius : -0.5679
#  charge : 15.842
#  radius : -0.1102
#  charge : 16.513
#  radius : 0.3531
#  charge : 15.998
#  radius : -0.4121
#  charge : 18.027
#  radius : -0.4121
#  charge : 15.419
#  radius : 0.2719
#  charge : 17.247
#  radius : 0.0922
#  charge : 14.861
#  radius : 0.0457
#  charge : 15.982
#  radius : 0.0457
#  charge : 16.327
#  radius : -0.0361
#  charge : 16.19
#  radius : 0.1
#  charge : 16.458
#  radius : 0.1
#  charge : 15.013
#  radius : 0.1
#  charge : 18.331
#  radius : 0.1
#  charge : 18.453
#  radius : 0.1
#  charge : 18.296
#  radius : 0.1
#  charge : 15.854
#  radius : -0.4157
#  radius : 0.1105
#  charge : 7.978
#  radius : -0.0173
#  charge : 7.763
#  radius : -0.0173
#  charge : 5.586
#  radius : -0.0425
#  charge : 5.855
#  radius : -0.0425
#  charge : 4.499
#  radius : -0.4157
#  charge : 3.545
#  radius : -0.0518
#  charge : 2.996
#  radius : 0.5973
#  charge : 2.131
#  radius : -0.5679
#  charge : 2.396
#  radius : -0.1102
#  charge : 1.322
#  radius : 0.3531
#  charge : 1.903
#  radius : -0.4121
#  charge : 0.336
#  radius : -0.4121
#  charge : 4.25
#  radius : 0.2719
#  charge : 4.022
#  radius : 0.0922
#  charge : 2.818
#  radius : 0.0457
#  charge : 1.942
#  radius : 0.0457
#  charge : 0.789
#  radius : -0.0361
#  charge : 2.416
#  radius : 0.1
#  charge : 1.156
#  radius : 0.1
#  charge : 2.509
#  radius : 0.1
#  charge : -0.074
#  radius : 0.1
#  charge : -0.386
#  radius : 0.1
#  charge : 0.81
#  radius : 0.1
#  charge : 3.534
#  radius : -0.4157
#  charge : 3.206
#  radius : -0.0518
#  charge : 1.814
#  radius : 0.5973
#  charge : 1.064
#  radius : -0.5679
#  charge : 4.286
#  radius : -0.1102
#  charge : 5.741
#  radius : 0.3531
#  charge : 6.62
#  radius : -0.4121
#  charge : 5.923
#  radius : -0.4121
#  charge : 4.196
#  radius : 0.2719
#  charge : 3.246
#  radius : 0.0922
#  charge : 4.223
#  radius : 0.0457
#  charge : 4.026
#  radius : 0.0457
#  charge : 6
#  radius : -0.0361
#  charge : 6.366
#  radius : 0.1
#  charge : 7.579
#  radius : 0.1
#  charge : 6.488
#  radius : 0.1
#  charge : 5.363
#  radius : 0.1
#  charge : 6.886
#  radius : 0.1
#  charge : 5.643
#  radius : 0.1
#  charge : 1.437
#  radius : -0.3479
#  charge : 0.33
#  radius : -0.24
#  charge : 0.029
#  radius : 0.7341
#  charge : 0.895
#  radius : -0.5894
#  charge : 0.867
#  radius : -0.0094
#  charge : 0.11
#  radius : 0.0187
#  charge : 0.948
#  radius : -0.0479
#  charge : 0.125
#  radius : -0.0143
#  charge : 0.781
#  radius : -0.3854
#  charge : 2.006
#  radius : 0.2747
#  charge : -0.467
#  radius : 0.1426
#  charge : 1.058
#  radius : 0.0362
#  charge : 1.808
#  radius : 0.0362
#  charge : 0.015
#  radius : 0.0103
#  charge : -0.755
#  radius : 0.0103
#  charge : 1.148
#  radius : 0.0621
#  charge : 1.755
#  radius : 0.0621
#  charge : -0.03
#  radius : 0.1135
#  charge : -0.772
#  radius : 0.1135
#  charge : 0.805
#  radius : 0.34
#  charge : 0.285
#  radius : 0.34
#  charge : 1.724
#  radius : 0.34
#  charge : -1.213
#  radius : -0.4157
#  charge : -1.629
#  radius : -0.0518
#  charge : -2.035
#  radius : 0.5973
#  charge : -2.605
#  radius : -0.5679
#  charge : -2.81
#  radius : -0.1102
#  charge : -2.575
#  radius : 0.3531
#  charge : -3.895
#  radius : -0.4121
#  charge : -1.58
#  radius : -0.4121
#  charge : -1.863
#  radius : 0.2719
#  charge : -0.861
#  radius : 0.0922
#  charge : -3.52
#  radius : 0.0457
#  charge : -3.175
#  radius : 0.0457
#  charge : -2.199
#  radius : -0.0361
#  charge : -4.281
#  radius : 0.1
#  charge : -3.755
#  radius : 0.1
#  charge : -4.537
#  radius : 0.1
#  charge : -0.716
#  radius : 0.1
#  charge : -1.439
#  radius : 0.1
#  charge : -1.961
#  radius : 0.1
#  charge : -1.697
#  radius : -0.5192
#  charge : -2.162
#  radius : -0.2059
#  charge : -2.745
#  radius : 0.742
#  charge : -2.752
#  radius : -0.793
#  charge : -1.003
#  radius : 0.0071
#  charge : -0.288
#  radius : 0.0675
#  charge : 0.99
#  radius : 0.8183
#  charge : 1.525
#  radius : -0.822
#  charge : 1.466
#  radius : -0.822
#  charge : -3.232
#  radius : -0.793
#  charge : -1.049
#  radius : 0.3055
#  charge : -2.872
#  radius : 0.1399
#  charge : -0.364
#  radius : -0.0078
#  charge : -1.348
#  radius : -0.0078
#  charge : -0.902
#  radius : -0.0548
#  charge : -0.052
#  radius : -0.0548
# Summary: 1/1 pairs successfully processed.

# %%
from htvs_amdock import analyze_htvs_results
analyze_htvs_results(new_1fkb_rap)
# Out:
# --- Summary for 1fkb_protein + rap ---
#
# === DOCKING LOG SUMMARY ===
#
# Log file: /home/daneel/gitrepos/gromacs_sims/htvs/1fkb_rap/job_1fkb_rap_script_20251213/1fkb_protein_rap_pipeline.log
#
# Detected tools / headers:
#   - propka_header: INFO:PROPKA information:
#   - pdb2pqr: 3.6.1
#   - vina: present
#
# PDB2PQR / structure info:
#   Residues: 107, Atoms: 1021
#
# PROPKA / pKa application:
#   pH applied: 7.4
#   Calculated pI (folded): 8.67
#   ======== PDB2PQR/PROPKA STDOUT ========
#   pKa entries parsed: 36
#   Lowest pKa residues (up to 5):
#          ASP 11A  pKa=1.99
#          ASP 37A  pKa=2.13
#          ASP 79A  pKa=2.71
#         ASP 100A  pKa=2.79
#          C- 107A  pKa=2.89
#   Highest pKa residues (up to 5):
#          ARG 71A  pKa=14.39
#          ARG 42A  pKa=14.31
#          ARG 57A  pKa=13.56
#          ARG 40A  pKa=12.83
#          ARG 13A  pKa=12.46
#
# AutoLigand (Automatic) site search:
#   Rank 1: Volume=247.0, EPV=-0.1932
#   Rank 2: Volume=295.0, EPV=-0.1640
#   Rank 3: Volume=303.0, EPV=-0.1627
#   Rank 4: Volume=249.0, EPV=-0.1558
#   Rank 5: Volume=278.0, EPV=-0.1478
#   Rank 6: Volume=275.0, EPV=-0.1452
#   Rank 7: Volume=302.0, EPV=-0.1351
#   Rank 8: Volume=362.0, EPV=-0.0979
#
# Affinities found in vina log files:
#
# Aggregated best affinities per pose:
#   Pose ID    Best Affinity (kcal/mol)
# ---------  --------------------------
#         1                     -10.88
#         2                     -10.84
#         5                     -10.83
#         3                     -10.81
#         6                      -8.979
#         7                      -6.649
#         8                      -6.454
#         4                      -6.191
#
# --- End of Summary for 1fkb_protein + rap ---

# %% [markdown]
# Nonmetal proteins are docking fine.
