# %% [markdown]
# Ku04AMP02 peptide and Phosphatedylethanolamine Complex
# ======================

# %% [markdown]
# ## ``Gromacs_py`` simulation
#
# Here is an example of a short simulation of the peptide (`Ku04AMP02`) protein in complex with phosphatedylethanolamine (`pea`) ligand using AMBER force-field model.
#
# The PDB file of ligand was taken from the Colpk_pyc simulation.
#
# Finally, nine successive steps are used:
#
# 1. Load the protein in its best -docked state.
#
# 2. In-complex creation of Protein Topology using ``GmxSys.add_top()``, followed by boxing and solvation/neutralization.
#
# 3. Boxing of complex.
#
# 4. Ideally, Ligand topology creation using `prepare_top()` which uses `acpype` to build ligand topology. This did not work, so must do this manually using `acpype` externally
#
# 5. Solvate complex and add ions.
#
# 6. Minimisation of the structure using ``GmxSys.em_2_steps()``.
#
# 7. Equilibration of the system using ``GmxSys.em_equi_three_step_iter_error()``.
#
# 8. Production run using ``GmxSys.production()``.
#
# 9.  Post-processing using `GmxSys.convert_trj().`
#
# ### Import

# %%
import sys
import os
import shutil

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## To use `gromacs_py` in a project

# %%
from gromacs_py import gmx

# %% [markdown]
# ## Simulation setup
#
# - Define a few variables for you simulation, like:
#
#     1. simulation output folders
#     2. ionic concentration
#     3. number of minimisation steps
#     4. equilibration and production time
#
# ### Regarding equilibriation time:
# The following variables define the sim times (relative units) for each stage of the three-stage equilibriation process. Check notes below for details:
#
# 1. `HA_time`
# 2. `CA_time`
# 3. `CA_LOW_time`

# %%
DATA_OUT = 'ku04amp02_pea_complex'

# System Setup
vsite='none'
sys_top_folder = os.path.join(DATA_OUT, 'sys_top')
#ignore_hydrogen = {'ignh': None}

# Energy Minimisation
em_folder = os.path.join(DATA_OUT, 'em')
em_sys_folder = os.path.join(DATA_OUT, 'sys_em')
em_step_number = 10000
emtol = 10.0  	# Stop minimization when the maximum force < 10 J/mol
emstep  = 0.01      # Energy step size


# Equillibration
equi_folder = os.path.join(DATA_OUT, 'sys_equi')
HA_time = 0.5
CA_time = 1.0
CA_LOW_time = 4.0

dt_HA = 0.001
dt = 0.002

HA_step = 1000 * HA_time / dt_HA
CA_step = 1000 * CA_time / dt
CA_LOW_step = 1000 * CA_LOW_time / dt

# Production
os.makedirs(DATA_OUT, exist_ok = True)
prod_folder = os.path.join(DATA_OUT, 'sys_prod')
prod_time = 50.0

prod_step = 1000 * prod_time / dt

# %% [markdown]
# ## Create the `GmxSys` object
#
# Load protein information only from docked PDB file on disk

# %%
# %%script true
#
# pdb_file = "pdbs/ku04amp02_pea.pdb"
# sys_name = "ku04amp02_pea_complex"
# complex_sys = gmx.GmxSys(name=sys_name, coor_file=pdb_file)

# %% [markdown]
# ## Create topology and stuff
#
# 1. Topology creation involves using `pdb2gmx` via the `prepare_top()` function.
# 2. Create box

# %%
# %%script true
# complex_sys.prepare_top(out_folder=DATA_OUT, ff='amber99sb-ildn')

# %% [markdown]
# ## Create Ligand topology and transclude manually to complex topology
#
# Doing this automatically in `gromacs_py` is buggy and doesn't work, necessitating manual overrides.
#
# 1. First, you need to add ALL hydrogen atoms into the PDB file of the best-docked ligand pose using pymol gui:
#     Load the ligand pdb into pymol, then click `builder -> add H` from the top right buttons. Save to new file.
#    **Note:** This yielded errors when running `acpype`, so I protonated with openbabel GUI @ pH: 7
# 3. Then run `acpype -i` on the resultant PDB from shell. These yield full ligand topology for multiple force fields. We're using the default AMBER force field here.
#
# 4. Next, copy-paste the contents of the ligand's amber force field topology file transclusions to the top of the complex topology file, AND the molecules section of the ligand's topology file to the molecules section of the complex topology file.
#
# **Note:** The ligand information MUST come FIRST in the complex topology, as there are new atomtypes in there and those must be defined first before any `moleculetype`. [See this](https://gromacs.bioexcel.eu/t/invalid-order-for-directive-atomtypes-error/3859)
#
# 4. Make sure to adjust the paths of all transcluded files.
#
# 5. Finally, update the complex PDB file with ligand co-ordinates from the best-docked pose using `pymol`.

# %%
# %%script true
# complex_sys.display()

# %%
# %%script true
# complex_sys.create_box(dist=1.5, box_type="dodecahedron", check_file_out=True)
# complex_sys.solvate_add_ions(out_folder=DATA_OUT, name=sys_name,create_box_flag=False, maxwarn=4)
# complex_sys.display()

# %% [markdown]
# ## Add index groups
#
# Now, we have to add the following index groups: Merge the Protein with the ligand (PYC) with the shell command
#
# ```bash
# gmx make_ndx -f ku04amp02_pea_complex_water_ion.gro -o ku04amp02_pea_complex_water_ion.ndx
# ```
# Merge group 1 with group 13 to form `Protein_PEA` group. We can now set temperature control groups to = `Protein_PEA` and `Water_and_ions` later.
#
# Finally, add the index file to the `complex_sys` object.

# %%
# %%script true
# complex_sys.add_ndx("",ndx_name="ku04amp02_pea_complex_water_ion", folder_out=DATA_OUT)

# %% [markdown]
# ## Energy minimisation
#
# Set parallelization and GPU options here. Change them later, if needed.

# %%
# %%script true
# #Parallelization
# nthreads = int(os.environ.get('PBS_NCPUS', '16'))
#
# #Set Parallelization
# complex_sys.nt = nthreads
# #complex_sys.ntmpi = 1
# complex_sys.gpu_id = '0'
#
# complex_sys.em_2_steps(out_folder=em_folder,
#         no_constr_nsteps=em_step_number,
#         constr_nsteps=em_step_number,
#         posres="",
#         create_box_flag=False, emtol=emtol, emstep=emstep)

# %% [markdown]
# ## Plot energy:

# %%
# %%script true
# ener_pd_1 = complex_sys.sys_history[-1].get_ener(selection_list=['Potential'])
# ener_pd_2 = complex_sys.get_ener(selection_list=['Potential'])
#
# ener_pd_1['label'] = 'no bond constr'
# ener_pd_2['label'] = 'bond constr'
#
# ener_pd = pd.concat([ener_pd_1, ener_pd_2])
#
# ener_pd['Time (ps)'] = np.arange(len(ener_pd))

# %%
# %%script true
# ax = sns.lineplot(x="Time (ps)", y="Potential",
#         hue="label",
#         data=ener_pd)
# ax.set_xlabel('step')
# ax.set_ylabel('energy (KJ/mol)')
# plt.grid()

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.em_' + datetime.date.today().strftime("%Y%m%d") + ".pycpt"
# with open(chkpt_fname, 'wb') as py_cpt:
#     pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ## From here, run in cluster
# ### System minimisation and equilibration
#
# Based on `gromacs_py` docs, this is a 3-stage equilibriation process.
#
# All three steps seem to be NPT with berendsen coupling and v-rescale for temp coupling. Each step just has different restraints. This does not seem so bad: closer to lab conditions.
#
# Since the statistical ensemble is pretty much always NPT, this is different from the Lemkul-lysozyme tutorial at [MDTutorials](http://www.mdtutorials.com/gmx/lysozyme/).
#
# **Note:**
# 1. Had to run this on cluster at least. Too slow even in ofc workstn.
# 2. Temperature coupling groups have to be set properly. See [mdtutorials](http://www.mdtutorials.com/gmx/complex/06_equil.html) and [gromacs-py manual](https://gromacs-py.readthedocs.io/en/latest/notebook/01_dna_ligand_ambertools.html#System-equilibration)
# 3. Ligand name is `PGL` as seen in the index file by visual inspection.

# %%
#%%script true
import pickle, datetime
chkpt_fname='checkpoint.em_20250807.pycpt'

with open(chkpt_fname, 'rb') as py_cpt:
    complex_sys = pickle.load(py_cpt)

# %%
#%%script true
#Parallelization
nthreads = int(os.environ.get('PBS_NCPUS', '12'))

#Set Parallelization
complex_sys.nt = nthreads
#complex_sys.ntmpi = 1
complex_sys.gpu_id = '0'

complex_sys.em_equi_three_step_iter_error(out_folder=equi_folder,
        no_constr_nsteps=em_step_number,
        constr_nsteps=em_step_number,
        nsteps_HA=HA_step,  
        nsteps_CA=CA_step,
        nsteps_CA_LOW=CA_LOW_step,
        dt=dt, dt_HA=dt_HA,
        tc_grps='Protein_PEA Water_and_ions',
        tau_t= '0.1 0.1',
        ref_t= '310 310',
        vsite=vsite, maxwarn=10, iter_num=1)
# Out:
# gmx grompp -f Init_em_ku04amp02_pea_complex.mdp -c ../../em/ku04amp02_pea_complex.gro -r ../../em/ku04amp02_pea_complex.gro -p ../../ku04amp02_pea_complex_water_ion.top -po out_Init_em_ku04amp02_pea_complex.mdp -o Init_em_ku04amp02_pea_complex.tpr -maxwarn 10 -n ../../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s Init_em_ku04amp02_pea_complex.tpr -deffnm Init_em_ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/10000 [00:00<?, ?it/s]
# gmx grompp -f ku04amp02_pea_complex.mdp -c Init_em_ku04amp02_pea_complex.gro -r Init_em_ku04amp02_pea_complex.gro -p ../../ku04amp02_pea_complex_water_ion.top -po out_ku04amp02_pea_complex.mdp -o ku04amp02_pea_complex.tpr -maxwarn 10 -n ../../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s ku04amp02_pea_complex.tpr -deffnm ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/10000 [00:00<?, ?it/s]
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_em/ku04amp02_pea_complex.gro -o ku04amp02_pea_complex/sys_equi/sys_em/ku04amp02_pea_complex_compact.pdb -s ku04amp02_pea_complex/sys_equi/sys_em/ku04amp02_pea_complex.tpr -ur compact -pbc mol -n ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx
# gmx grompp -f equi_HA_ku04amp02_pea_complex.mdp -c ../../sys_em/ku04amp02_pea_complex_compact.pdb -r ../../sys_em/ku04amp02_pea_complex_compact.pdb -p ../../../ku04amp02_pea_complex_water_ion.top -po out_equi_HA_ku04amp02_pea_complex.mdp -o equi_HA_ku04amp02_pea_complex.tpr -maxwarn 10 -n ../../../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s equi_HA_ku04amp02_pea_complex.tpr -deffnm equi_HA_ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/500000 [00:00<?, ?it/s]
# gmx grompp -f equi_CA_ku04amp02_pea_complex.mdp -c ../00_equi_HA/equi_HA_ku04amp02_pea_complex.gro -r ../../sys_em/ku04amp02_pea_complex_compact.pdb -p ../../../ku04amp02_pea_complex_water_ion.top -po out_equi_CA_ku04amp02_pea_complex.mdp -o equi_CA_ku04amp02_pea_complex.tpr -maxwarn 10 -n ../../../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s equi_CA_ku04amp02_pea_complex.tpr -deffnm equi_CA_ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/500000 [00:00<?, ?it/s]
# gmx grompp -f equi_CA_LOW_ku04amp02_pea_complex.mdp -c ../01_equi_CA/equi_CA_ku04amp02_pea_complex.gro -r ../../sys_em/ku04amp02_pea_complex_compact.pdb -p ../../../ku04amp02_pea_complex_water_ion.top -po out_equi_CA_LOW_ku04amp02_pea_complex.mdp -o equi_CA_LOW_ku04amp02_pea_complex.tpr -maxwarn 10 -n ../../../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s equi_CA_LOW_ku04amp02_pea_complex.tpr -deffnm equi_CA_LOW_ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/2000000 [00:00<?, ?it/s]

# %%
#%%script true
import pickle, datetime
chkpt_fname='checkpoint.equi_' + datetime.date.today().strftime("%Y%m%d") + ".pycpt"
with open(chkpt_fname, 'wb') as py_cpt:
    pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ### Plot Equilibriation
#
# Since the statistical ensemble is pretty much always NPT, this is different from the Lemkul-lysozyme tutorial at [MDTutorials](http://www.mdtutorials.com/gmx/lysozyme/). So we need to see Volume as well as Pressure, temperature, and density.

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.equi_20250117.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %%
#%%script true
quantities = ["Temperature", "Pressure", "Volume", "Density"]
units = ["$K$", "$bar$", "$A^3$", "$kg/m^3$"]

pd_1 = complex_sys.sys_history[-2].get_ener(selection_list=quantities)
pd_2 = complex_sys.sys_history[-1].get_ener(selection_list=quantities)
pd_3 = complex_sys.get_ener(selection_list=quantities)

pd_1['label'] = 'HA_constr'
pd_2['label'] = 'CA_constr'
pd_2['Time (ps)'] = pd_2['Time (ps)'] + pd_1['Time (ps)'].max()
pd_3['label'] = 'CA_LOW_constr'
pd_3['Time (ps)'] = pd_3['Time (ps)'] + pd_2['Time (ps)'].max()

display(pd.concat([pd_1, pd_2, pd_3]))
# Out:
# gmx energy -f ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.edr -o tmp_edr.xvg
# gmx energy -f ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.edr -o tmp_edr.xvg
# gmx energy -f ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.edr -o tmp_edr.xvg
#      Time (ps)  Temperature     Pressure      Volume      Density  \
# 0          0.0     0.171487 -4026.700195  284.820862   980.530945
# 1          5.0   308.161041     1.552705  280.828094   994.471924
# 2         10.0   309.632935    28.947611  280.485535   995.686523
# 3         15.0   311.496094  -194.198563  280.090088   997.092285
# 4         20.0   308.881317   -81.583214  280.100800   997.054138
# ..         ...          ...          ...         ...          ...
# 396     5460.0   311.521851   241.794113  276.504761  1010.021179
# 397     5470.0   310.543762  -196.783646  281.459290   992.241760
# 398     5480.0   308.622986  -202.312302  281.383759   992.508118
# 399     5490.0   311.624237   243.006973  279.023010  1000.905457
# 400     5500.0   311.005707    81.972420  279.078979  1000.704773
#
#              label
# 0        HA_constr
# 1        HA_constr
# 2        HA_constr
# 3        HA_constr
# 4        HA_constr
# ..             ...
# 396  CA_LOW_constr
# 397  CA_LOW_constr
# 398  CA_LOW_constr
# 399  CA_LOW_constr
# 400  CA_LOW_constr
#
# [603 rows x 6 columns]

# %%
#%%script true
plt.rcParams.update({'font.size': 22})

fig, axs = plt.subplots(4, 1, figsize=(24,13.5), sharex=True, tight_layout=True)

for ax, quantity, unit in zip(axs, quantities, units):
    for df in (pd_1, pd_2, pd_3):
        ax.plot(df["Time (ps)"], df[quantity], label=str(df['label'][0]))
        ax.set_ylabel(quantity + "(" + unit + ")")
        ax.grid()

axs[0].legend()
axs[-1].set_xlabel("Time (ps)");

# %% [markdown]
# Looks okay to me. Fluctuations are high at the end because CA constraints are low, but there is a well-defined average.

# %% [markdown]
# ### Plot RMSD
#
# There is a corrupted frame in the `xtc` (probably took place during checkpoint restore) due to which this doesn't work. Nonetheless, the `gro` file of the final state looks good, so will proceed to production MD.

# %%
#%%script true
# Define reference structure for RMSD calculation
ref_sys =  complex_sys.sys_history[1]
struct="Protein"

rmsd_pd_1 = complex_sys.sys_history[-2].get_rmsd([struct, struct], ref_sys=ref_sys)
rmsd_pd_2 = complex_sys.sys_history[-1].get_rmsd([struct, struct], ref_sys=ref_sys)
rmsd_pd_3 = complex_sys.get_rmsd([struct, struct], ref_sys=ref_sys)


rmsd_pd_1['label'] = 'HA_constr'
rmsd_pd_2['label'] = 'CA_constr'
rmsd_pd_2['time'] = rmsd_pd_2['time'] + rmsd_pd_1['time'].max()
rmsd_pd_3['label'] = 'CA_LOW_constr'
rmsd_pd_3['time'] = rmsd_pd_3['time'] + rmsd_pd_2['time'].max()

display(pd.concat([rmsd_pd_1, rmsd_pd_2, rmsd_pd_3]))
# Out:
# gmx rms -s ku04amp02_pea_complex/em/Init_em_ku04amp02_pea_complex.tpr -f ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.xtc -n ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
# gmx rms -s ku04amp02_pea_complex/em/Init_em_ku04amp02_pea_complex.tpr -f ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.xtc -n ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
# gmx rms -s ku04amp02_pea_complex/em/Init_em_ku04amp02_pea_complex.tpr -f ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.xtc -n ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx -o tmp_rmsd.xvg -fit rot+trans -ng 1 -pbc no
#        time   Protein          label
# 0       0.0  0.292013      HA_constr
# 1       5.0  0.296991      HA_constr
# 2      10.0  0.297486      HA_constr
# 3      15.0  0.297932      HA_constr
# 4      20.0  0.295438      HA_constr
# ..      ...       ...            ...
# 396  5460.0  0.418785  CA_LOW_constr
# 397  5470.0  0.422882  CA_LOW_constr
# 398  5480.0  0.423752  CA_LOW_constr
# 399  5490.0  0.417183  CA_LOW_constr
# 400  5500.0  0.426677  CA_LOW_constr
#
# [603 rows x 3 columns]

# %%
#%%script true
fig, ax = plt.subplots(1, 1, figsize=(24,13.5))

for df in (rmsd_pd_1, rmsd_pd_2, rmsd_pd_3):
        ax.plot(df["time"], df["Protein"], label=str(df['label'][0]))
        
ax.set_title(struct)
ax.set_ylabel('RMSD (nm)')
ax.set_xlabel('Time (ps)')
plt.grid()

# %% [markdown]
# ## Production MD
#
# tc-coupling groups are required here as well. See [gromacs-py manual](https://gromacs-py.readthedocs.io/en/latest/notebook/01_dna_ligand_ambertools.html#Production)

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.equi_20250117.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %%
#%%script true
#Parallelization
nthreads = int(os.environ.get('PBS_NCPUS', '16'))

#Set Parallelization
complex_sys.nt = nthreads
#complex_sys.ntmpi = 1
complex_sys.gpu_id = '0'

complex_sys.production(out_folder=prod_folder,
        nsteps=prod_step,
        tc_grps='Protein_PEA Water_and_ions',
        tau_t= '0.1 0.1',
        ref_t= '310 310',
        dt=dt, vsite=vsite, maxwarn=1, nstlist=200)
# Out:
# gmx grompp -f prod_ku04amp02_pea_complex.mdp -c ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.gro -r ../sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.gro -p ../ku04amp02_pea_complex_water_ion.top -po out_prod_ku04amp02_pea_complex.mdp -o prod_ku04amp02_pea_complex.tpr -maxwarn 1 -n ../ku04amp02_pea_complex_water_ion.ndx
# gmx mdrun -s prod_ku04amp02_pea_complex.tpr -deffnm prod_ku04amp02_pea_complex -nt 32 -ntmpi 0 -nsteps -2 -nocopyright -gpu_id 0
#   0%|          | 0/25000000 [00:00<?, ?it/s]

# %% [markdown]
# ## Checkpointing for extending

# %%
#%%script true
import pickle, datetime
chkpt_fname='checkpoint.prod_' + datetime.date.today().strftime("%Y%m%d") + '.pycpt'
with open(chkpt_fname, 'wb') as py_cpt:
    pickle.dump(complex_sys, py_cpt)

# %% [markdown]
# ## Post-Production

# %%
# %%script true
# import pickle, datetime
# chkpt_fname='checkpoint.prod_20250118.pycpt'
#
# with open(chkpt_fname, 'rb') as py_cpt:
#     complex_sys = pickle.load(py_cpt)

# %% [markdown]
# ### Prepare Production Trajectory for Viewing
#
# #### Center Trajectory

# %%
#%%script true
# Center trajectory
complex_sys.center_mol_box(traj=True)
# Out:
# gmx make_ndx -f ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.gro -o ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.xtc -o ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex_compact.xtc -s ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.tpr -ur tric -pbc mol -center yes -n ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.ndx

# %% [markdown]
# ## Final Steps
# As in any simulation conducted with periodic boundary conditions, molecules may appear "broken" or may "jump" back and forth across the box. To recenter the protein and rewrap the molecules within the unit cell to recover the desired box shape, invoke trjconv.
#
# Choose "Protein" for centering and "System" for output.

# %%
#%%script true
complex_sys.convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none')
# Out:
# gmx trjconv -f ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex_compact.xtc -o ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex_compact_compact.xtc -s ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.tpr -ur compact -pbc none -fit rot+trans -n ku04amp02_pea_complex/sys_prod/prod_ku04amp02_pea_complex.ndx

# %% [markdown]
# #### Extract production initial condition
# Optionally, extract the first frame of the final prod traj (latest from history, as the running one got updated) into a `pdb` for loading into post processing.

# %%
#%%script true
complex_sys.sys_history[-1].convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none', specific_coor_out=prod_folder+"/start.pdb", dump="0")
# Out:
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.xtc -o ku04amp02_pea_complex/sys_prod/start.pdb -s ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.tpr -ur compact -pbc none -dump 0 -fit rot+trans -n ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx

# %% [markdown]
# ### Cleanup older trajectories the same way

# %%
#%%script true
complex_sys.sys_history[5].display()
# Out:
# name         : ku04amp02_pea_complex
# sim_name     : equi_HA_ku04amp02_pea_complex
# coor_file    : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.gro
# top_file     : ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.top
# tpr          : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.tpr
# ndx          : ku04amp02_pea_complex/ku04amp02_pea_complex_water_ion.ndx
# mdp          : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.mdp
# xtc          : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.xtc
# edr          : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.edr
# log          : ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.log
# nt           : 32
# ntmpi        : 0
# gpu_id       : 0
# sys_history  : 0

# %% [markdown]
# Visual inspection of sys_history shows that elements 5,6,7 contain the equilibration history.

# %%
#%%script true
idx = [5,6,7]

for i in idx:
    try:
        complex_sys.sys_history[i].center_mol_box(traj=True)
        complex_sys.sys_history[i].convert_trj(select='Protein\nSystem', fit='rot+trans', pbc='none')
    except:
        pass
# Out:
# gmx make_ndx -f ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.gro -o ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.xtc -o ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.tpr -ur tric -pbc mol -center yes -n ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex_compact.xtc -o ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex_compact_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.tpr -ur compact -pbc none -fit rot+trans -n ku04amp02_pea_complex/sys_equi/sys_equi/00_equi_HA/equi_HA_ku04amp02_pea_complex.ndx
# gmx make_ndx -f ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.gro -o ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.xtc -o ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.tpr -ur tric -pbc mol -center yes -n ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex_compact.xtc -o ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex_compact_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.tpr -ur compact -pbc none -fit rot+trans -n ku04amp02_pea_complex/sys_equi/sys_equi/01_equi_CA/equi_CA_ku04amp02_pea_complex.ndx
# gmx make_ndx -f ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.gro -o ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_prod/start.pdb -o ku04amp02_pea_complex/sys_prod/start_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.tpr -ur tric -pbc mol -center yes -n ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.ndx
# gmx trjconv -f ku04amp02_pea_complex/sys_prod/start_compact.xtc -o ku04amp02_pea_complex/sys_prod/start_compact_compact.xtc -s ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.tpr -ur compact -pbc none -fit rot+trans -n ku04amp02_pea_complex/sys_equi/sys_equi/02_equi_CA_LOW/equi_CA_LOW_ku04amp02_pea_complex.ndx
