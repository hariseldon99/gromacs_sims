# %% [markdown]
# ## Modelling multiple protein structures together
#
#
# We use a combination of homology and alphafold (AI models) available in SWISSMODEL, the automated protein structure homology-modelling server, accessible via the Expasy web server.
#
# Directly taken from;
#
# https://swissmodel.expasy.org/docs/help#modelling_api
#
#
#
#
# Steps:
#
# 1. Obtain API token: Downloaded from account @ swissmodel and stored in file @ ~/.config/swissmodel/apikey.txt
# 2. Then, Load all provided fasta sequences

# %%
from Bio import SeqIO

# Read the FASTA file and store sequences in a dictionary
fasta_dict = {}
with open("pseudomonas_sequences.fna", "r") as fasta_file:
    for record in SeqIO.parse(fasta_file, "fasta"):
        fasta_dict[record.id] = str(record.seq)

# %% [markdown]
# 3. Start Automodel projects for each sequence

# %%
import os

apikey_path = os.path.expanduser("~/.config/swissmodel/apikey.txt")
with open(apikey_path, 'r') as f:
    api_key = f.read().strip()

print("API Key imported successfully:", api_key)

# %%
import requests


for record_id, sequence in fasta_dict.items():
    print(f"Submitting sequence for {record_id} ...")
    response = requests.post(
        "https://swissmodel.expasy.org/automodel",
        headers={ "Authorization": f"Token {api_key}" },
        json={ 
            "target_sequences": [sequence],
            "project_title": f"Automodelling project for {record_id}"
        }
    )
    if response.status_code == 202:
        print(f"Submission for {record_id} successful.")
        if 'responses_by_record' not in globals():
            responses_by_record = {}
        responses_by_record[record_id] = response
    else:
        print(f"Error submitting {record_id}: {response.status_code} - {response.text}")
# Out:
# Submitting sequence for 2012|D0E7M2|D0E7M2_PSEAI ...
# Submission for 2012|D0E7M2|D0E7M2_PSEAI successful.
# Submitting sequence for 2016|WP_063840509.1:61-251 ...
# Submission for 2016|WP_063840509.1:61-251 successful.
# Submitting sequence for 1999|Q9ZNQ0|Q9ZNQ0_PSEAI ...
# Submission for 1999|Q9ZNQ0|Q9ZNQ0_PSEAI successful.
# Submitting sequence for 2007|A6VD77|A6VD77_PSEA7 ...
# Submission for 2007|A6VD77|A6VD77_PSEA7 successful.
# Submitting sequence for 2014|W1MT92|W1MT92_PSEAI ...
# Submission for 2014|W1MT92|W1MT92_PSEAI successful.
# Submitting sequence for 2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB ...
# Submission for 2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB successful.
# Submitting sequence for 2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI ...
# Submission for 2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI successful.
# Submitting sequence for 1999|Q9X6V3|Q9X6V3_PSEAI ...
# Submission for 1999|Q9X6V3|Q9X6V3_PSEAI successful.
# Submitting sequence for 2015|A0A0A8RE86|A0A0A8RE86_PSEAI ...
# Submission for 2015|A0A0A8RE86|A0A0A8RE86_PSEAI successful.
# Submitting sequence for 2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI ...
# Submission for 2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI successful.
# Submitting sequence for 1996|P48372|GYRA_PSEAE ...
# Submission for 1996|P48372|GYRA_PSEAE successful.
# Submitting sequence for 2007|A6V2Q7|A6V2Q7_PSEA7 ...
# Submission for 2007|A6V2Q7|A6V2Q7_PSEA7 successful.
# Submitting sequence for 2018A|A0A2R3INH2|A0A2R3INH2_PSEAI ...
# Submission for 2018A|A0A2R3INH2|A0A2R3INH2_PSEAI successful.
# Submitting sequence for 2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI ...
# Submission for 2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI successful.

# %% [markdown]
# 4. Fetch the results

# %%
r = responses_by_record['2012|D0E7M2|D0E7M2_PSEAI']
project_id = r.json()["project_id"]

r_new = requests.get(
        f"https://swissmodel.expasy.org/project/{ project_id }/models/summary/", 
        headers={ "Authorization": f"Token {api_key}" })
r_new.json()
# Out:
# {'project_id': '53a3c0',
#  'status': 'INITIALISED',
#  'models': None,
#  'date_created': '2025-04-11T05:26:09.111523Z',
#  'project_title': 'Automodelling project for 2012|D0E7M2|D0E7M2_PSEAI'}

# %%
for record_id, sequence in fasta_dict.items():
    print(f"Submitting sequence for {record_id} ...")
    response = responses_by_record[record_id]
    if response.status_code == 202:
        print(f"Submission for {record_id} successful.")
    else:
        print(f"Error submitting {record_id}: {response.status_code} - {response.text}")

    # Obtain the project_id from the response created above
    project_id = response.json()["project_id"]

    
    # Update the status from the server 
    response = requests.get(
        f"https://swissmodel.expasy.org/project/{ project_id }/models/summary/", 
        headers={ "Authorization": f"Token {api_key}" })

    # Update the status
    status = response.json()["status"]

    print('Job status is now', status)
# Out:
# Submitting sequence for 2012|D0E7M2|D0E7M2_PSEAI ...
# Submission for 2012|D0E7M2|D0E7M2_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2016|WP_063840509.1:61-251 ...
# Submission for 2016|WP_063840509.1:61-251 successful.
# Job status is now INITIALISED
# Submitting sequence for 1999|Q9ZNQ0|Q9ZNQ0_PSEAI ...
# Submission for 1999|Q9ZNQ0|Q9ZNQ0_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2007|A6VD77|A6VD77_PSEA7 ...
# Submission for 2007|A6VD77|A6VD77_PSEA7 successful.
# Job status is now INITIALISED
# Submitting sequence for 2014|W1MT92|W1MT92_PSEAI ...
# Submission for 2014|W1MT92|W1MT92_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB ...
# Submission for 2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB successful.
# Job status is now INITIALISED
# Submitting sequence for 2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI ...
# Submission for 2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 1999|Q9X6V3|Q9X6V3_PSEAI ...
# Submission for 1999|Q9X6V3|Q9X6V3_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2015|A0A0A8RE86|A0A0A8RE86_PSEAI ...
# Submission for 2015|A0A0A8RE86|A0A0A8RE86_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI ...
# Submission for 2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 1996|P48372|GYRA_PSEAE ...
# Submission for 1996|P48372|GYRA_PSEAE successful.
# Job status is now INITIALISED
# Submitting sequence for 2007|A6V2Q7|A6V2Q7_PSEA7 ...
# Submission for 2007|A6V2Q7|A6V2Q7_PSEA7 successful.
# Job status is now INITIALISED
# Submitting sequence for 2018A|A0A2R3INH2|A0A2R3INH2_PSEAI ...
# Submission for 2018A|A0A2R3INH2|A0A2R3INH2_PSEAI successful.
# Job status is now INITIALISED
# Submitting sequence for 2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI ...
# Submission for 2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI successful.
# Job status is now INITIALISED

# %% [markdown]
# 5. Check if the job is COMPLETED and fetch the model coordinates

# %%
import os
import gzip
import shutil
import tqdm.notebook as tqdm
# Create a directory to store the downloaded models
out_dir = "downloaded_models"
os.makedirs(out_dir, exist_ok=True)

for record_id, sequence in fasta_dict.items():
    response = responses_by_record[record_id]
    response_object = response.json()
    if response_object['status']=='COMPLETED':
        for model in response_object['models']:
            print(model['modelcif_url'])    # ModelCif Format
            print(model['coordinates_url']) # PDB Format
            # For each model, download the coordinates file in PDB format
            url = model["coordinates_url"]
            download_response = requests.get(url)
            if download_response.status_code == 200:
                # Save using model_id in filename to distinguish files
                filename = os.path.join(out_dir, f"{record_id}_{model['model_id']}_coordinates.pdb.gz")
                with open(filename, "wb") as f:
                    f.write(download_response.content)
                # Remove the .gz extension to get the target pdb filename
                unp_file = filename[:-3]

                # Decompress the .gz file to a .pdb file
                with gzip.open(filename, 'rb') as f_in, open(unp_file, 'wb') as f_out:
                    shutil.copyfileobj(f_in, f_out)

                # Read the decompressed pdb file content
                with open(unp_file, 'r') as pdb_in:
                    pdb_content = pdb_in.read()

                # Prepend REMARK lines containing the record id and its fasta sequence 
                remarks = f"REMARK Record ID: {record_id}\nREMARK Sequence: {fasta_dict[record_id]}\n"
                with open(unp_file, 'w') as pdb_out:
                    pdb_out.write(remarks + pdb_content)
                print("Downloaded:", filename)
            else:
                print("Failed to download:", url)
# Out:
# https://swissmodel.expasy.org/project/4e76ca/models/01.cif.gz
# https://swissmodel.expasy.org/project/4e76ca/models/01.pdb.gz
# Downloaded: downloaded_models/01_coordinates.pdb.gz

# %%
old_projectids = [
    "da6be8",
    "01049c",
    "086f25",
    "084b59",
    "b04f1d",
    "54b0ee",
    "372310",
    "d3fb0c",
    "e73c1d",
    "70a89d",
    "005c96",
    "b70498",
    "ace2d9",
    "2a6ce4"
]

old_sequences = [
    "2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI",
    "2018A|A0A2R3INH2|A0A2R3INH2_PSEAI",
    "2007|A6V2Q7|A6V2Q7_PSEA7",
    "1996|P48372|GYRA_PSEAE",
    "2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI",
    "2015|A0A0A8RE86|A0A0A8RE86_PSEAI",
    "1999|Q9X6V3|Q9X6V3_PSEAI",
    "2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI",
    "2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB",
    "2014|W1MT92|W1MT92_PSEAI",
    "2007|A6VD77|A6VD77_PSEA7",
    "1999|Q9ZNQ0|Q9ZNQ0_PSEAI",
    "2016|WP_063840509.1:61-251",
    "2012|D0E7M2|D0E7M2_PSEAI"
]
old_sequences.reverse()
# Out:
# ['2012|D0E7M2|D0E7M2_PSEAI',
#  '2016|WP_063840509.1:61-251',
#  '1999|Q9ZNQ0|Q9ZNQ0_PSEAI',
#  '2007|A6VD77|A6VD77_PSEA7',
#  '2014|W1MT92|W1MT92_PSEAI',
#  '2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB',
#  '2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI',
#  '1999|Q9X6V3|Q9X6V3_PSEAI',
#  '2015|A0A0A8RE86|A0A0A8RE86_PSEAI',
#  '2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI',
#  '1996|P48372|GYRA_PSEAE',
#  '2007|A6V2Q7|A6V2Q7_PSEA7',
#  '2018A|A0A2R3INH2|A0A2R3INH2_PSEAI',
#  '2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI']

# %%
import os
import gzip
import shutil
out_dir = "downloaded_models"

for i, pid in enumerate(old_projectids):
    
    # Update the status from the server 
    response = requests.get(
        f"https://swissmodel.expasy.org/project/{pid}/models/summary/", 
        headers={"Authorization": f"Token {api_key}"})

    # Update the status
    status = response.json()["status"]
    response_json  = response.json()
    print('Job status is now', status)
    print(response_json)
    for model in response_json['models']:
            print(model['coordinates_url']) # PDB Format
            # For each model, download the coordinates file in PDB format
            url = model["coordinates_url"]
            download_response = requests.get(url)
            if download_response.status_code == 200:
                # Save using model_id in filename to distinguish files
                if model['model_id'] == '01':
                    filename = os.path.join(out_dir, f"{old_sequences[i]}_{model['model_id']}_coordinates.pdb.gz")
                    with open(filename, "wb") as f:
                        f.write(download_response.content)
                    # Remove the .gz extension to get the target pdb filename
                    unp_file = filename[:-3]

                    # Decompress the .gz file to a .pdb file
                    with gzip.open(filename, 'rb') as f_in, open(unp_file, 'wb') as f_out:
                        shutil.copyfileobj(f_in, f_out)

                    # Read the decompressed pdb file content
                    with open(unp_file, 'r') as pdb_in:
                        pdb_content = pdb_in.read()

                    # Prepend REMARK lines containing the record id and its fasta sequence 
                    remarks = f"REMARK Record ID: {record_id}\nREMARK Sequence: {fasta_dict[record_id]}\n"
                    with open(unp_file, 'w') as pdb_out:
                        pdb_out.write(remarks + pdb_content)
                    print("Downloaded:", filename)
                else:
                    print("Failed to download:", url)
# Out:
# Job status is now COMPLETED
# {'project_id': 'da6be8', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.9, 'qmean_global': {'avg_local_score': 0.84}, 'coordinates_url': 'https://swissmodel.expasy.org/project/da6be8/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/da6be8/models/01.cif.gz'}], 'date_created': '2025-04-09T16:38:30.976108Z', 'project_title': 'Automodelling project for 2012|D0E7M2|D0E7M2_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/da6be8/view'}
# https://swissmodel.expasy.org/project/da6be8/models/01.pdb.gz
# Downloaded: downloaded_models/2012|D0E7M2|D0E7M2_PSEAI_01_coordinates.pdb.gz
# Job status is now COMPLETED
# {'project_id': '01049c', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.9, 'qmean_global': {'avg_local_score': 0.85}, 'coordinates_url': 'https://swissmodel.expasy.org/project/01049c/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/01049c/models/01.cif.gz'}], 'date_created': '2025-04-09T16:38:32.671314Z', 'project_title': 'Automodelling project for 2016|WP_063840509.1:61-251', 'view_url': 'https://swissmodel.expasy.org/project/01049c/view'}
# https://swissmodel.expasy.org/project/01049c/models/01.pdb.gz
# Downloaded: downloaded_models/2016|WP_063840509.1:61-251_01_coordinates.pdb.gz
# Job status is now COMPLETED
# {'project_id': '086f25', 'status': 'COMPLETED', 'models': [{'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.93, 'coordinates_url': 'https://swissmodel.expasy.org/project/086f25/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/086f25/models/02.cif.gz'}, {'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.78, 'qmean_global': {'avg_local_score': 0.77}, 'coordinates_url': 'https://swissmodel.expasy.org/project/086f25/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/086f25/models/01.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.69, 'qmean_global': {'avg_local_score': 0.68}, 'coordinates_url': 'https://swissmodel.expasy.org/project/086f25/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/086f25/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.55, 'qmean_global': {'avg_local_score': 0.81}, 'coordinates_url': 'https://swissmodel.expasy.org/project/086f25/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/086f25/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:35.012855Z', 'project_title': 'Automodelling project for 1999|Q9ZNQ0|Q9ZNQ0_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/086f25/view'}
# https://swissmodel.expasy.org/project/086f25/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/086f25/models/02.pdb.gz
# https://swissmodel.expasy.org/project/086f25/models/01.pdb.gz
# Downloaded: downloaded_models/1999|Q9ZNQ0|Q9ZNQ0_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/086f25/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/086f25/models/04.pdb.gz
# https://swissmodel.expasy.org/project/086f25/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/086f25/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': '084b59', 'status': 'COMPLETED', 'models': [{'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.93, 'coordinates_url': 'https://swissmodel.expasy.org/project/084b59/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/084b59/models/02.cif.gz'}, {'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.78, 'qmean_global': {'avg_local_score': 0.77}, 'coordinates_url': 'https://swissmodel.expasy.org/project/084b59/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/084b59/models/01.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.69, 'qmean_global': {'avg_local_score': 0.68}, 'coordinates_url': 'https://swissmodel.expasy.org/project/084b59/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/084b59/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.54, 'qmean_global': {'avg_local_score': 0.81}, 'coordinates_url': 'https://swissmodel.expasy.org/project/084b59/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/084b59/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:38.673235Z', 'project_title': 'Automodelling project for 2007|A6VD77|A6VD77_PSEA7', 'view_url': 'https://swissmodel.expasy.org/project/084b59/view'}
# https://swissmodel.expasy.org/project/084b59/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/084b59/models/02.pdb.gz
# https://swissmodel.expasy.org/project/084b59/models/01.pdb.gz
# Downloaded: downloaded_models/2007|A6VD77|A6VD77_PSEA7_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/084b59/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/084b59/models/04.pdb.gz
# https://swissmodel.expasy.org/project/084b59/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/084b59/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': 'b04f1d', 'status': 'COMPLETED', 'models': [{'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.93, 'coordinates_url': 'https://swissmodel.expasy.org/project/b04f1d/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b04f1d/models/02.cif.gz'}, {'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.78, 'qmean_global': {'avg_local_score': 0.77}, 'coordinates_url': 'https://swissmodel.expasy.org/project/b04f1d/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b04f1d/models/01.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.69, 'qmean_global': {'avg_local_score': 0.68}, 'coordinates_url': 'https://swissmodel.expasy.org/project/b04f1d/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b04f1d/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.54, 'qmean_global': {'avg_local_score': 0.8}, 'coordinates_url': 'https://swissmodel.expasy.org/project/b04f1d/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b04f1d/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:40.547742Z', 'project_title': 'Automodelling project for 2014|W1MT92|W1MT92_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/b04f1d/view'}
# https://swissmodel.expasy.org/project/b04f1d/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/b04f1d/models/02.pdb.gz
# https://swissmodel.expasy.org/project/b04f1d/models/01.pdb.gz
# Downloaded: downloaded_models/2014|W1MT92|W1MT92_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/b04f1d/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/b04f1d/models/04.pdb.gz
# https://swissmodel.expasy.org/project/b04f1d/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/b04f1d/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': '54b0ee', 'status': 'COMPLETED', 'models': [{'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.93, 'coordinates_url': 'https://swissmodel.expasy.org/project/54b0ee/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/54b0ee/models/02.cif.gz'}, {'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.78, 'qmean_global': {'avg_local_score': 0.77}, 'coordinates_url': 'https://swissmodel.expasy.org/project/54b0ee/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/54b0ee/models/01.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.69, 'qmean_global': {'avg_local_score': 0.68}, 'coordinates_url': 'https://swissmodel.expasy.org/project/54b0ee/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/54b0ee/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.54, 'qmean_global': {'avg_local_score': 0.8}, 'coordinates_url': 'https://swissmodel.expasy.org/project/54b0ee/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/54b0ee/models/03.cif.gz'}, {'model_id': '05', 'status': 'COMPLETED', 'gmqe': 0.1, 'qmean_global': {'avg_local_score': 0.47}, 'coordinates_url': 'https://swissmodel.expasy.org/project/54b0ee/models/05.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/54b0ee/models/05.cif.gz'}], 'date_created': '2025-04-09T16:38:42.108030Z', 'project_title': 'Automodelling project for 2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB', 'view_url': 'https://swissmodel.expasy.org/project/54b0ee/view'}
# https://swissmodel.expasy.org/project/54b0ee/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/54b0ee/models/02.pdb.gz
# https://swissmodel.expasy.org/project/54b0ee/models/01.pdb.gz
# Downloaded: downloaded_models/2015|A0A0H2ZL55|A0A0H2ZL55_PSEAB_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/54b0ee/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/54b0ee/models/04.pdb.gz
# https://swissmodel.expasy.org/project/54b0ee/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/54b0ee/models/03.pdb.gz
# https://swissmodel.expasy.org/project/54b0ee/models/05.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/54b0ee/models/05.pdb.gz
# Job status is now COMPLETED
# {'project_id': '372310', 'status': 'COMPLETED', 'models': [{'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.93, 'coordinates_url': 'https://swissmodel.expasy.org/project/372310/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/372310/models/02.cif.gz'}, {'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.78, 'qmean_global': {'avg_local_score': 0.77}, 'coordinates_url': 'https://swissmodel.expasy.org/project/372310/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/372310/models/01.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.69, 'qmean_global': {'avg_local_score': 0.68}, 'coordinates_url': 'https://swissmodel.expasy.org/project/372310/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/372310/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.54, 'qmean_global': {'avg_local_score': 0.81}, 'coordinates_url': 'https://swissmodel.expasy.org/project/372310/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/372310/models/03.cif.gz'}, {'model_id': '05', 'status': 'COMPLETED', 'gmqe': 0.1, 'qmean_global': {'avg_local_score': 0.48}, 'coordinates_url': 'https://swissmodel.expasy.org/project/372310/models/05.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/372310/models/05.cif.gz'}], 'date_created': '2025-04-09T16:38:43.581921Z', 'project_title': 'Automodelling project for 2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/372310/view'}
# https://swissmodel.expasy.org/project/372310/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/372310/models/02.pdb.gz
# https://swissmodel.expasy.org/project/372310/models/01.pdb.gz
# Downloaded: downloaded_models/2018|A0A3A1ZXK0|A0A3A1ZXK0_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/372310/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/372310/models/04.pdb.gz
# https://swissmodel.expasy.org/project/372310/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/372310/models/03.pdb.gz
# https://swissmodel.expasy.org/project/372310/models/05.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/372310/models/05.pdb.gz
# Job status is now COMPLETED
# {'project_id': 'd3fb0c', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.9, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.73, 'qmean_global': {'avg_local_score': 0.75}, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.68, 'qmean_global': {'avg_local_score': 0.76}, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/03.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.6, 'qmean_global': {'avg_local_score': 0.62}, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/04.cif.gz'}, {'model_id': '05', 'status': 'COMPLETED', 'gmqe': 0.56, 'qmean_global': {'avg_local_score': 0.61}, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/05.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/05.cif.gz'}, {'model_id': '06', 'status': 'COMPLETED', 'gmqe': 0.53, 'qmean_global': {'avg_local_score': 0.57}, 'coordinates_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/06.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/d3fb0c/models/06.cif.gz'}], 'date_created': '2025-04-09T16:38:45.082345Z', 'project_title': 'Automodelling project for 1999|Q9X6V3|Q9X6V3_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/d3fb0c/view'}
# https://swissmodel.expasy.org/project/d3fb0c/models/01.pdb.gz
# Downloaded: downloaded_models/1999|Q9X6V3|Q9X6V3_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/d3fb0c/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/d3fb0c/models/02.pdb.gz
# https://swissmodel.expasy.org/project/d3fb0c/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/d3fb0c/models/03.pdb.gz
# https://swissmodel.expasy.org/project/d3fb0c/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/d3fb0c/models/04.pdb.gz
# https://swissmodel.expasy.org/project/d3fb0c/models/05.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/d3fb0c/models/05.pdb.gz
# https://swissmodel.expasy.org/project/d3fb0c/models/06.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/d3fb0c/models/06.pdb.gz
# Job status is now COMPLETED
# {'project_id': 'e73c1d', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.9, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.73, 'qmean_global': {'avg_local_score': 0.74}, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.68, 'qmean_global': {'avg_local_score': 0.76}, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/03.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.6, 'qmean_global': {'avg_local_score': 0.62}, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/04.cif.gz'}, {'model_id': '05', 'status': 'COMPLETED', 'gmqe': 0.56, 'qmean_global': {'avg_local_score': 0.61}, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/05.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/05.cif.gz'}, {'model_id': '06', 'status': 'COMPLETED', 'gmqe': 0.53, 'qmean_global': {'avg_local_score': 0.57}, 'coordinates_url': 'https://swissmodel.expasy.org/project/e73c1d/models/06.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/e73c1d/models/06.cif.gz'}], 'date_created': '2025-04-09T16:38:46.707014Z', 'project_title': 'Automodelling project for 2015|A0A0A8RE86|A0A0A8RE86_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/e73c1d/view'}
# https://swissmodel.expasy.org/project/e73c1d/models/01.pdb.gz
# Downloaded: downloaded_models/2015|A0A0A8RE86|A0A0A8RE86_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/e73c1d/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/e73c1d/models/02.pdb.gz
# https://swissmodel.expasy.org/project/e73c1d/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/e73c1d/models/03.pdb.gz
# https://swissmodel.expasy.org/project/e73c1d/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/e73c1d/models/04.pdb.gz
# https://swissmodel.expasy.org/project/e73c1d/models/05.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/e73c1d/models/05.pdb.gz
# https://swissmodel.expasy.org/project/e73c1d/models/06.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/e73c1d/models/06.pdb.gz
# Job status is now COMPLETED
# {'project_id': '70a89d', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.9, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.73, 'qmean_global': {'avg_local_score': 0.74}, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.68, 'qmean_global': {'avg_local_score': 0.76}, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/03.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.6, 'qmean_global': {'avg_local_score': 0.62}, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/04.cif.gz'}, {'model_id': '05', 'status': 'COMPLETED', 'gmqe': 0.56, 'qmean_global': {'avg_local_score': 0.61}, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/05.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/05.cif.gz'}, {'model_id': '06', 'status': 'COMPLETED', 'gmqe': 0.53, 'qmean_global': {'avg_local_score': 0.57}, 'coordinates_url': 'https://swissmodel.expasy.org/project/70a89d/models/06.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/70a89d/models/06.cif.gz'}], 'date_created': '2025-04-09T16:38:48.121469Z', 'project_title': 'Automodelling project for 2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/70a89d/view'}
# https://swissmodel.expasy.org/project/70a89d/models/01.pdb.gz
# Downloaded: downloaded_models/2018|A0A2R3ILK4|A0A2R3ILK4_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/70a89d/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/70a89d/models/02.pdb.gz
# https://swissmodel.expasy.org/project/70a89d/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/70a89d/models/03.pdb.gz
# https://swissmodel.expasy.org/project/70a89d/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/70a89d/models/04.pdb.gz
# https://swissmodel.expasy.org/project/70a89d/models/05.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/70a89d/models/05.pdb.gz
# https://swissmodel.expasy.org/project/70a89d/models/06.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/70a89d/models/06.pdb.gz
# Job status is now COMPLETED
# {'project_id': '005c96', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.85, 'coordinates_url': 'https://swissmodel.expasy.org/project/005c96/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/005c96/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.72, 'qmean_global': {'avg_local_score': 0.74}, 'coordinates_url': 'https://swissmodel.expasy.org/project/005c96/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/005c96/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.49, 'qmean_global': {'avg_local_score': 0.59}, 'coordinates_url': 'https://swissmodel.expasy.org/project/005c96/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/005c96/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:51.601967Z', 'project_title': 'Automodelling project for 1996|P48372|GYRA_PSEAE', 'view_url': 'https://swissmodel.expasy.org/project/005c96/view'}
# https://swissmodel.expasy.org/project/005c96/models/01.pdb.gz
# Downloaded: downloaded_models/1996|P48372|GYRA_PSEAE_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/005c96/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/005c96/models/02.pdb.gz
# https://swissmodel.expasy.org/project/005c96/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/005c96/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': 'b70498', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.85, 'coordinates_url': 'https://swissmodel.expasy.org/project/b70498/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b70498/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.73, 'qmean_global': {'avg_local_score': 0.75}, 'coordinates_url': 'https://swissmodel.expasy.org/project/b70498/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b70498/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.49, 'qmean_global': {'avg_local_score': 0.6}, 'coordinates_url': 'https://swissmodel.expasy.org/project/b70498/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/b70498/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:53.035122Z', 'project_title': 'Automodelling project for 2007|A6V2Q7|A6V2Q7_PSEA7', 'view_url': 'https://swissmodel.expasy.org/project/b70498/view'}
# https://swissmodel.expasy.org/project/b70498/models/01.pdb.gz
# Downloaded: downloaded_models/2007|A6V2Q7|A6V2Q7_PSEA7_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/b70498/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/b70498/models/02.pdb.gz
# https://swissmodel.expasy.org/project/b70498/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/b70498/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': 'ace2d9', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.85, 'coordinates_url': 'https://swissmodel.expasy.org/project/ace2d9/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/ace2d9/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.73, 'qmean_global': {'avg_local_score': 0.75}, 'coordinates_url': 'https://swissmodel.expasy.org/project/ace2d9/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/ace2d9/models/02.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.49, 'qmean_global': {'avg_local_score': 0.59}, 'coordinates_url': 'https://swissmodel.expasy.org/project/ace2d9/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/ace2d9/models/03.cif.gz'}], 'date_created': '2025-04-09T16:38:54.619767Z', 'project_title': 'Automodelling project for 2018A|A0A2R3INH2|A0A2R3INH2_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/ace2d9/view'}
# https://swissmodel.expasy.org/project/ace2d9/models/01.pdb.gz
# Downloaded: downloaded_models/2018A|A0A2R3INH2|A0A2R3INH2_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/ace2d9/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/ace2d9/models/02.pdb.gz
# https://swissmodel.expasy.org/project/ace2d9/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/ace2d9/models/03.pdb.gz
# Job status is now COMPLETED
# {'project_id': '2a6ce4', 'status': 'COMPLETED', 'models': [{'model_id': '01', 'status': 'COMPLETED', 'gmqe': 0.89, 'coordinates_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/01.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/01.cif.gz'}, {'model_id': '02', 'status': 'COMPLETED', 'gmqe': 0.7, 'qmean_global': {'avg_local_score': 0.7}, 'coordinates_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/02.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/02.cif.gz'}, {'model_id': '04', 'status': 'COMPLETED', 'gmqe': 0.48, 'qmean_global': {'avg_local_score': 0.82}, 'coordinates_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/04.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/04.cif.gz'}, {'model_id': '03', 'status': 'COMPLETED', 'gmqe': 0.05, 'qmean_global': {'avg_local_score': 0.39}, 'coordinates_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/03.pdb.gz', 'modelcif_url': 'https://swissmodel.expasy.org/project/2a6ce4/models/03.cif.gz'}], 'date_created': '2025-04-09T16:39:00.555122Z', 'project_title': 'Automodelling project for 2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI', 'view_url': 'https://swissmodel.expasy.org/project/2a6ce4/view'}
# https://swissmodel.expasy.org/project/2a6ce4/models/01.pdb.gz
# Downloaded: downloaded_models/2018B|A0A2X4EZ45|A0A2X4EZ45_PSEAI_01_coordinates.pdb.gz
# https://swissmodel.expasy.org/project/2a6ce4/models/02.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/2a6ce4/models/02.pdb.gz
# https://swissmodel.expasy.org/project/2a6ce4/models/04.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/2a6ce4/models/04.pdb.gz
# https://swissmodel.expasy.org/project/2a6ce4/models/03.pdb.gz
# Failed to download: https://swissmodel.expasy.org/project/2a6ce4/models/03.pdb.gz
